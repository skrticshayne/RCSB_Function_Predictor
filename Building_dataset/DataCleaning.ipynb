# %%
import pandas as pd
import os

# Load the CSV file into a DataFrame
file_path = "/Users/shayneskrtic/Desktop/data_copy.csv"
df = pd.read_csv(file_path)

# Drop duplicates based on the 'pdb_id' column
df = df.drop_duplicates(subset=['pdb_id'])

# Get the initial number of rows before dropping empty 'ec_numbers'
initial_rows = df.shape[0]

# Drop rows where 'ec_numbers' column is empty
df = df[df['ec_numbers'].apply(lambda x: len(eval(x)) > 0)]

# Get the final number of rows after dropping empty 'ec_numbers'
final_rows = df.shape[0]

# Calculate the number of dropped rows
dropped_rows = initial_rows - final_rows

print(f"Number of dropped rows: {dropped_rows}")

# Create new file name by appending "_dropped_null_ec" to the original file name
new_file_path = os.path.splitext(file_path)[0] + '_dropped_null_ec.csv'

# Write the DataFrame to a new CSV file
df.to_csv(new_file_path, index=False)

print(f"DataFrame has been written to {new_file_path}")
# Out:
# Number of dropped rows: 1537
# DataFrame has been written to /Users/shayneskrtic/Desktop/data_copy_dropped_null_ec.csv

# %%
path = "/Users/shayneskrtic/Desktop/data_copy.csv"

# %%
import pandas as pd
import ast

def load_and_extract_signatures(csv_file_path):
    df = pd.read_csv(csv_file_path)
    unique_signatures = set()
    
    for motifs in df['motifs']:
        motifs_list = ast.literal_eval(motifs)
        for motif in motifs_list:
            unique_signatures.add(motif['signature_ac'])
    
    unique_signatures_list = sorted(list(unique_signatures))
    return unique_signatures_list


csv_file_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec.csv'
unique_signatures = load_and_extract_signatures(csv_file_path)
print(len(unique_signatures))
# Out:
# 392

# %%
import pandas as pd
import ast
aa_groups = {
    'Hydrophobic': ['A', 'V', 'I', 'L', 'M', 'F', 'W', 'Y'],
    'Polar': ['S', 'T', 'N', 'Q', 'C'],
    'Basic': ['K', 'R', 'H'],
    'Acidic': ['D', 'E'],
    'Special': ['G', 'P']
}

def group_aa_frequencies(aa_percent, aa_groups):
    grouped_data = {group: 0 for group in aa_groups.keys()}
    for aa, freq in aa_percent.items():
        for group, aas in aa_groups.items():
            if aa in aas:
                grouped_data[group] += freq
                break
    return grouped_data
def process_csv(input_csv_path, output_csv_path):
    df = pd.read_csv(input_csv_path)
    
    hydrophobic = []
    polar = []
    basic = []
    acidic = []
    special = []
    
    # Iterate over each row in the DataFrame
    for aa_percent_str in df['amino_acid_Percent']:
        # Convert the string representation of the dictionary to an actual dictionary
        aa_percent = ast.literal_eval(aa_percent_str)
        
        # Group the frequencies
        grouped_frequencies = group_aa_frequencies(aa_percent, aa_groups)
        
        # Append the grouped frequencies to the respective lists
        hydrophobic.append(grouped_frequencies['Hydrophobic'])
        polar.append(grouped_frequencies['Polar'])
        basic.append(grouped_frequencies['Basic'])
        acidic.append(grouped_frequencies['Acidic'])
        special.append(grouped_frequencies['Special'])
    
    # Add the new columns to the DataFrame
    df['Hydrophobic'] = hydrophobic
    df['Polar'] = polar
    df['Basic'] = basic
    df['Acidic'] = acidic
    df['Special'] = special
    
    # Save the updated DataFrame to a new CSV file
    df.to_csv(output_csv_path, index=False)

# Example usage
input_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec.csv'
output_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS.csv'
process_csv(input_csv_path, output_csv_path)
print(f"Processed CSV saved to {output_csv_path}")
# Out:
# Processed CSV saved to /Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS.csv

# %%
import pandas as pd

def load_and_clean_csv(input_csv_path, output_csv_path):
    # Load the CSV file into a pandas DataFrame
    df = pd.read_csv(input_csv_path)
    
    # Drop rows where 'percent_else' column value is less than 0
    df_cleaned = df[df['percent_else'] >= 0]
    
    # Save the cleaned DataFrame to a new CSV file
    df_cleaned.to_csv(output_csv_path, index=False)

# Example usage
input_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS.csv'
output_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible.csv'
load_and_clean_csv(input_csv_path, output_csv_path)
print(f"Cleaned CSV saved to {output_csv_path}")
# Out:
# Cleaned CSV saved to /Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible.csv

# %%
import pandas as pd
from Bio.PDB import PDBList, PDBParser
import os

def get_oligomeric_state(pdb_id):
    # Download the PDB file
    pdbl = PDBList()
    pdb_file = pdbl.retrieve_pdb_file(pdb_id, file_format='pdb')
    
    # Parse the PDB file
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure(pdb_id, pdb_file)
    
    # Get the number of chains
    chains = set()
    for model in structure:
        for chain in model:
            chains.add(chain.id)
    
    # Determine the oligomeric state
    num_chains = len(chains)
    if num_chains == 1:
        oligomeric_state = "Monomer"
    elif num_chains == 2:
        oligomeric_state = "Dimer"
    elif num_chains == 3:
        oligomeric_state = "Trimer"
    elif num_chains == 4:
        oligomeric_state = "Tetramer"
    else:
        oligomeric_state = f"Oligomer with {num_chains} chains"
    
    # Delete the PDB file
    os.remove(pdb_file)
    
    return oligomeric_state

def process_pdb_ids(input_csv_path, output_csv_path):
    # Load the CSV file into a pandas DataFrame
    df = pd.read_csv(input_csv_path)
    
    # Initialize a list to store the oligomeric states
    oligomeric_states = []
    
    # Iterate over each PDB ID in the DataFrame
    for pdb_id in df['pdb_id']:
        oligomeric_state = get_oligomeric_state(pdb_id)
        oligomeric_states.append(oligomeric_state)
    
    # Add the new column to the DataFrame
    df['oligomeric_state'] = oligomeric_states
    
    # Save the updated DataFrame to a new CSV file
    df.to_csv(output_csv_path, index=False)

# Example usage
input_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible.csv'
output_csv_path = '/Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible_Chains.csv'
process_pdb_ids(input_csv_path, output_csv_path)
print(f"Processed CSV saved to {output_csv_path}")
# Out:
# Downloading PDB structure '1v48'...
# Downloading PDB structure '4but'...
# Downloading PDB structure '7mrr'...
# Downloading PDB structure '4hl5'...
# Downloading PDB structure '8s69'...
# Downloading PDB structure '9f6j'...
# Downloading PDB structure '7gph'...
# Downloading PDB structure '2gkl'...
# Downloading PDB structure '6eqw'...
# Downloading PDB structure '8hht'...
# Downloading PDB structure '7gfb'...
# Downloading PDB structure '3cui'...
# Downloading PDB structure '4ecz'...
# Downloading PDB structure '3ero'...
# Downloading PDB structure '1wop'...
# Downloading PDB structure '4l7g'...
# Downloading PDB structure '6y6j'...
# Downloading PDB structure '7gf7'...
# Downloading PDB structure '1u4o'...
# Downloading PDB structure '7ghb'...
# Downloading PDB structure '2pny'...
# Downloading PDB structure '7a16'...
# Downloading PDB structure '5rx6'...
# Downloading PDB structure '9f6l'...
# Downloading PDB structure '3t90'...
# Downloading PDB structure '8bsd'...
# Downloading PDB structure '8qew'...
# Downloading PDB structure '4bu8'...
# Downloading PDB structure '5iiq'...
# Downloading PDB structure '4l09'...
# Downloading PDB structure '7ltj'...
# Downloading PDB structure '4rd6'...
# Downloading PDB structure '5rf7'...
# Downloading PDB structure '1o2w'...
# Downloading PDB structure '3pm3'...
# Downloading PDB structure '6fcc'...
# Downloading PDB structure '4uvw'...
# Downloading PDB structure '3c5q'...
# Downloading PDB structure '1ceg'...
# Downloading PDB structure '5y7t'...
# Downloading PDB structure '3cmq'...
# Downloading PDB structure '1ase'...
# Downloading PDB structure '5n84'...
# Downloading PDB structure '1o38'...
# Downloading PDB structure '6ukd'...
# Downloading PDB structure '6z82'...
# Downloading PDB structure '8jco'...
# Downloading PDB structure '5kfc'...
# Downloading PDB structure '4bus'...
# Downloading PDB structure '5i6y'...
# Downloading PDB structure '4j1k'...
# Downloading PDB structure '8u2p'...
# Downloading PDB structure '1g9b'...
# Downloading PDB structure '7mc5'...
# Downloading PDB structure '3zc5'...
# Downloading PDB structure '6ql0'...
# Downloading PDB structure '5zyb'...
# Downloading PDB structure '5rh6'...
# Downloading PDB structure '5tye'...
# Downloading PDB structure '4c4i'...
# Downloading PDB structure '6pl7'...
# Downloading PDB structure '6dor'...
# Downloading PDB structure '1ihs'...
# Downloading PDB structure '4acx'...
# Downloading PDB structure '3s7l'...
# Downloading PDB structure '5tyw'...
# Downloading PDB structure '7gaz'...
# Downloading PDB structure '5tyv'...
# Downloading PDB structure '1i9z'...
# Downloading PDB structure '4uvp'...
# Downloading PDB structure '5a1g'...
# Downloading PDB structure '5eyc'...
# Downloading PDB structure '1yw8'...
# Downloading PDB structure '1hvq'...
# Downloading PDB structure '6g0a'...
# Downloading PDB structure '4buv'...
# Downloading PDB structure '1ruv'...
# Downloading PDB structure '5ows'...
# Downloading PDB structure '5f6l'...
# Downloading PDB structure '5al4'...
# Downloading PDB structure '2ys6'...
# Downloading PDB structure '7ukk'...
# Downloading PDB structure '7gft'...
# Downloading PDB structure '7a12'...
# Downloading PDB structure '6vf9'...
# Downloading PDB structure '7ans'...
# Downloading PDB structure '5e8m'...
# Downloading PDB structure '1yry'...
# Downloading PDB structure '6lip'...
# Downloading PDB structure '2gjp'...
# Downloading PDB structure '5rfk'...
# Downloading PDB structure '5i3v'...
# Downloading PDB structure '7gpr'...
# Downloading PDB structure '1o3j'...
# Downloading PDB structure '8s2q'...
# Downloading PDB structure '1o2t'...
# Downloading PDB structure '4da7'...
# Downloading PDB structure '1v9h'...
# Downloading PDB structure '2g4u'...
# Downloading PDB structure '7gpj'...
# Downloading PDB structure '5nfv'...
# Downloading PDB structure '7jir'...
# Downloading PDB structure '2b46'...
# Downloading PDB structure '4kzq'...
# Downloading PDB structure '4nbp'...
# Downloading PDB structure '5rwq'...
# Downloading PDB structure '5ads'...
# Downloading PDB structure '8u9w'...
# Downloading PDB structure '3ckk'...
# Downloading PDB structure '7gbq'...
# Downloading PDB structure '2puh'...
# Downloading PDB structure '7goz'...
# Downloading PDB structure '7tiu'...
# Downloading PDB structure '7gb0'...
# Downloading PDB structure '1r5g'...
# Downloading PDB structure '1jnu'...
# Downloading PDB structure '2zq1'...
# Downloading PDB structure '7ghd'...
# Downloading PDB structure '3hhm'...
# Downloading PDB structure '4ui6'...
# Downloading PDB structure '1s3u'...
# Downloading PDB structure '7gel'...
# Downloading PDB structure '2std'...
# Downloading PDB structure '8hy3'...
# Downloading PDB structure '5oa8'...
# Downloading PDB structure '6yxb'...
# Downloading PDB structure '8pg9'...
# Downloading PDB structure '3ovx'...
# Downloading PDB structure '6w4h'...
# Downloading PDB structure '1lkd'...
# Downloading PDB structure '3mhj'...
# Downloading PDB structure '5twr'...
# Downloading PDB structure '6d1k'...
# Downloading PDB structure '7z6a'...
# Downloading PDB structure '5wkj'...
# Downloading PDB structure '5f9n'...
# Downloading PDB structure '8qdz'...
# Downloading PDB structure '4uvv'...
# Downloading PDB structure '7bhv'...
# Downloading PDB structure '6w6d'...
# Downloading PDB structure '3axt'...
# Downloading PDB structure '7gba'...
# Downloading PDB structure '7gd0'...
# Downloading PDB structure '7ge7'...
# Downloading PDB structure '7gcm'...
# Downloading PDB structure '1j1f'...
# Downloading PDB structure '3v1n'...
# Downloading PDB structure '6bdy'...
# Downloading PDB structure '8qia'...
# Downloading PDB structure '5daq'...
# Downloading PDB structure '6ksr'...
# Downloading PDB structure '6i1s'...
# Downloading PDB structure '1r0p'...
# Downloading PDB structure '3rv4'...
# Downloading PDB structure '7f9r'...
# Downloading PDB structure '8h9a'...
# Downloading PDB structure '1gi6'...
# Downloading PDB structure '5r84'...
# Downloading PDB structure '6zat'...
# Downloading PDB structure '5ry1'...
# Downloading PDB structure '3pd3'...
# Downloading PDB structure '3pk6'...
# Downloading PDB structure '2bu6'...
# Downloading PDB structure '1a9t'...
# Downloading PDB structure '1r5h'...
# Downloading PDB structure '6xjk'...
# Downloading PDB structure '9enq'...
# Downloading PDB structure '1cet'...
# Downloading PDB structure '2zdk'...
# Downloading PDB structure '1mra'...
# Downloading PDB structure '5dg7'...
# Downloading PDB structure '4wyy'...
# Downloading PDB structure '6bwq'...
# Downloading PDB structure '7ap6'...
# Downloading PDB structure '3uax'...
# Downloading PDB structure '8shb'...
# Downloading PDB structure '4aoi'...
# Downloading PDB structure '1gi4'...
# Downloading PDB structure '6d0m'...
# Downloading PDB structure '3ctj'...
# Downloading PDB structure '6h9x'...
# Downloading PDB structure '3v7p'...
# Downloading PDB structure '5ewe'...
# Downloading PDB structure '1art'...
# Downloading PDB structure '6k9t'...
# Downloading PDB structure '5tp0'...
# Downloading PDB structure '6s1s'...
# Downloading PDB structure '7gdg'...
# Downloading PDB structure '2r9n'...
# Downloading PDB structure '5ryi'...
# Downloading PDB structure '6gli'...
# Downloading PDB structure '5sml'...
# Downloading PDB structure '4xux'...
# Downloading PDB structure '3zbs'...
# Downloading PDB structure '5rg2'...
# Downloading PDB structure '1rob'...
# Downloading PDB structure '6rr2'...
# Downloading PDB structure '5za0'...
# Downloading PDB structure '8ov4'...
# Downloading PDB structure '6nri'...
# Downloading PDB structure '5dlf'...
# Downloading PDB structure '4gvu'...
# Downloading PDB structure '4m04'...
# Downloading PDB structure '7rwh'...
# Downloading PDB structure '6akh'...
# Downloading PDB structure '3inf'...
# Downloading PDB structure '4l2k'...
# Downloading PDB structure '5nut'...
# Downloading PDB structure '6obf'...
# Downloading PDB structure '5ogh'...
# Downloading PDB structure '7m83'...
# Downloading PDB structure '3p4e'...
# Downloading PDB structure '4hhd'...
# Downloading PDB structure '5ylt'...
# Downloading PDB structure '1nb0'...
# Downloading PDB structure '5msd'...
# Downloading PDB structure '7ef9'...
# Downloading PDB structure '4dvi'...
# Downloading PDB structure '5reg'...
# Downloading PDB structure '4ab8'...
# Downloading PDB structure '5dga'...
# Downloading PDB structure '5c1u'...
# Downloading PDB structure '3cla'...
# Downloading PDB structure '2owb'...
# Downloading PDB structure '6ipe'...
# Downloading PDB structure '7qt9'...
# Downloading PDB structure '6d4f'...
# Downloading PDB structure '8sty'...
# Downloading PDB structure '3n3g'...
# Downloading PDB structure '5wij'...
# Downloading PDB structure '2yzl'...
# Downloading PDB structure '5rw7'...
# Downloading PDB structure '1gi1'...
# Downloading PDB structure '6avl'...
# Downloading PDB structure '3dbd'...
# Downloading PDB structure '5zf3'...
# Downloading PDB structure '8c5m'...
# Downloading PDB structure '7gdj'...
# Downloading PDB structure '4o86'...
# Downloading PDB structure '3gy6'...
# Downloading PDB structure '4o29'...
# Downloading PDB structure '2rl5'...
# Downloading PDB structure '1eiz'...
# Downloading PDB structure '5kfb'...
# Downloading PDB structure '1f31'...
# Downloading PDB structure '3n0h'...
# Downloading PDB structure '1atl'...
# Downloading PDB structure '6v61'...
# Downloading PDB structure '7tob'...
# Downloading PDB structure '8pal'...
# Downloading PDB structure '3iog'...
# Downloading PDB structure '3fr0'...
# Downloading PDB structure '8qi8'...
# Downloading PDB structure '7fum'...
# Downloading PDB structure '1fj6'...
# Downloading PDB structure '8rfu'...
# Downloading PDB structure '7z25'...
# Downloading PDB structure '7gha'...
# Downloading PDB structure '3rsv'...
# Downloading PDB structure '1i7c'...
# Downloading PDB structure '7kt9'...
# Downloading PDB structure '4ygi'...
# Downloading PDB structure '1a9p'...
# Downloading PDB structure '8ex2'...
# Downloading PDB structure '7gpt'...
# Downloading PDB structure '6m65'...
# Downloading PDB structure '5ayc'...
# Downloading PDB structure '3m54'...
# Downloading PDB structure '5rw8'...
# Downloading PDB structure '5ry4'...
# Downloading PDB structure '8jck'...
# Downloading PDB structure '7m8d'...
# Downloading PDB structure '7gds'...
# Downloading PDB structure '8uab'...
# Downloading PDB structure '5x5g'...
# Downloading PDB structure '5mcq'...
# Downloading PDB structure '1kk3'...
# Downloading PDB structure '3avo'...
# Downloading PDB structure '1nw5'...
# Downloading PDB structure '8d59'...
# Downloading PDB structure '1nqc'...
# Downloading PDB structure '4qdd'...
# Downloading PDB structure '7gdb'...
# Downloading PDB structure '3vfc'...
# Downloading PDB structure '7gfm'...
# Downloading PDB structure '3wwc'...
# Downloading PDB structure '3zbx'...
# Downloading PDB structure '8pgx'...
# Downloading PDB structure '7gfq'...
# Downloading PDB structure '3r2y'...
# Downloading PDB structure '8rfo'...
# Downloading PDB structure '8b04'...
# Downloading PDB structure '7ktd'...
# Downloading PDB structure '2xd4'...
# Downloading PDB structure '2bu7'...
# Downloading PDB structure '5zqp'...
# Downloading PDB structure '5itd'...
# Downloading PDB structure '4j1i'...
# Downloading PDB structure '8pgy'...
# Downloading PDB structure '7akg'...
# Downloading PDB structure '7axo'...
# Downloading PDB structure '8pg3'...
# Downloading PDB structure '7gqc'...
# Downloading PDB structure '7a13'...
# Downloading PDB structure '8tpi'...
# Downloading PDB structure '5ony'...
# Downloading PDB structure '7gb1'...
# Downloading PDB structure '6liz'...
# Downloading PDB structure '2h03'...
# Downloading PDB structure '8rgc'...
# Downloading PDB structure '3zcl'...
# Downloading PDB structure '7gqj'...
# Downloading PDB structure '5jhu'...
# Downloading PDB structure '8ryj'...
# Downloading PDB structure '7cd9'...
# Downloading PDB structure '1nc6'...
# Downloading PDB structure '5nve'...
# Downloading PDB structure '6hld'...
# Downloading PDB structure '5nt4'...
# Downloading PDB structure '5zii'...
# Downloading PDB structure '8v7b'...
# Downloading PDB structure '5jxh'...
# Downloading PDB structure '7bhu'...
# Downloading PDB structure '6zav'...
# Downloading PDB structure '6qeg'...
# Downloading PDB structure '5kfq'...
# Downloading PDB structure '1yk7'...
# Downloading PDB structure '6pau'...
# Downloading PDB structure '3twd'...
# Downloading PDB structure '7gdd'...
# Downloading PDB structure '1o2s'...
# Downloading PDB structure '7go5'...
# Downloading PDB structure '5rwh'...
# Downloading PDB structure '3v8m'...
# Downloading PDB structure '5a00'...
# Downloading PDB structure '6rc0'...
# Downloading PDB structure '6r1o'...
# Downloading PDB structure '4bs4'...
# Downloading PDB structure '3anv'...
# Downloading PDB structure '5kfj'...
# Downloading PDB structure '5tyg'...
# Downloading PDB structure '2dej'...
# Downloading PDB structure '3k8q'...
# Downloading PDB structure '6rar'...
# Downloading PDB structure '5jxj'...
# Downloading PDB structure '3pkf'...
# Downloading PDB structure '1ny3'...
# Downloading PDB structure '7gc6'...
# Downloading PDB structure '5gwa'...
# Downloading PDB structure '7kce'...
# Downloading PDB structure '7gbf'...
# Downloading PDB structure '2ex9'...
# Downloading PDB structure '5rgn'...
# Downloading PDB structure '3pn4'...
# Downloading PDB structure '8gfo'...
# Downloading PDB structure '7gnx'...
# Downloading PDB structure '6l7x'...
# Downloading PDB structure '1o33'...
# Downloading PDB structure '7s73'...
# Downloading PDB structure '5fqo'...
# Downloading PDB structure '7aku'...
# Downloading PDB structure '8r6b'...
# Downloading PDB structure '7tq8'...
# Downloading PDB structure '5a67'...
# Downloading PDB structure '5rex'...
# Downloading PDB structure '2ex8'...
# Downloading PDB structure '3ua9'...
# Downloading PDB structure '5kft'...
# Downloading PDB structure '9bs2'...
# Downloading PDB structure '3l3a'...
# Downloading PDB structure '7lcd'...
# Downloading PDB structure '8s9z'...
# Downloading PDB structure '8qir'...
# Downloading PDB structure '7gdc'...
# Downloading PDB structure '5rgp'...
# Downloading PDB structure '7gh2'...
# Downloading PDB structure '5kfl'...
# Downloading PDB structure '7m7p'...
# Downloading PDB structure '5lz9'...
# Downloading PDB structure '2ph6'...
# Downloading PDB structure '3ivh'...
# Downloading PDB structure '8v7d'...
# Downloading PDB structure '4dcd'...
# Downloading PDB structure '2ohr'...
# Downloading PDB structure '2ejt'...
# Downloading PDB structure '2vm3'...
# Downloading PDB structure '5e3p'...
# Downloading PDB structure '3ijz'...
# Downloading PDB structure '3m42'...
# Downloading PDB structure '8pg2'...
# Downloading PDB structure '5iby'...
# Downloading PDB structure '3zv9'...
# Downloading PDB structure '3ej2'...
# Downloading PDB structure '1ga0'...
# Downloading PDB structure '5d81'...
# Downloading PDB structure '2e9m'...
# Downloading PDB structure '5zri'...
# Downloading PDB structure '3buh'...
# Downloading PDB structure '4b72'...
# Downloading PDB structure '1i1n'...
# Downloading PDB structure '8qiv'...
# Downloading PDB structure '8rfr'...
# Downloading PDB structure '1v3q'...
# Downloading PDB structure '5rgk'...
# Downloading PDB structure '7bht'...
# Downloading PDB structure '7gqb'...
# Downloading PDB structure '7aqe'...
# Downloading PDB structure '5ryl'...
# Downloading PDB structure '6nss'...
# Downloading PDB structure '5dqg'...
# Downloading PDB structure '4n3m'...
# Downloading PDB structure '1u3l'...
# Downloading PDB structure '6d1b'...
# Downloading PDB structure '1o2o'...
# Downloading PDB structure '4yd1'...
# Downloading PDB structure '8uw8'...
# Downloading PDB structure '8ov3'...
# Downloading PDB structure '4j21'...
# Downloading PDB structure '1elf'...
# Downloading PDB structure '1eks'...
# Downloading PDB structure '4rcf'...
# Downloading PDB structure '6jsg'...
# Downloading PDB structure '6w1h'...
# Downloading PDB structure '7go0'...
# Downloading PDB structure '5nwg'...
# Downloading PDB structure '5akw'...
# Downloading PDB structure '1mvs'...
# Downloading PDB structure '4xst'...
# Downloading PDB structure '4c08'...
# Downloading PDB structure '4uvu'...
# Downloading PDB structure '1npz'...
# Downloading PDB structure '4dmy'...
# Downloading PDB structure '4rrq'...
# Downloading PDB structure '6nrh'...
# Downloading PDB structure '3fhr'...
# Downloading PDB structure '2a4o'...
# Downloading PDB structure '5a57'...
# Downloading PDB structure '7gf9'...
# Downloading PDB structure '7ksv'...
# Downloading PDB structure '4wz4'...
# Downloading PDB structure '7lyi'...
# Downloading PDB structure '2yoz'...
# Downloading PDB structure '2g8j'...
# Downloading PDB structure '3bjp'...
# Downloading PDB structure '8hyd'...
# Downloading PDB structure '8um5'...
# Downloading PDB structure '1snk'...
# Downloading PDB structure '4ojx'...
# Downloading PDB structure '6k0e'...
# Downloading PDB structure '7est'...
# Downloading PDB structure '7lcq'...
# Downloading PDB structure '7jit'...
# Downloading PDB structure '7gp1'...
# Downloading PDB structure '7gq7'...
# Downloading PDB structure '1jy8'...
# Downloading PDB structure '1nvr'...
# Downloading PDB structure '2fqd'...
# Downloading PDB structure '6kwg'...
# Downloading PDB structure '3zmg'...
# Downloading PDB structure '5ygy'...
# Downloading PDB structure '6ydy'...
# Downloading PDB structure '4dl5'...
# Downloading PDB structure '5l1j'...
# Downloading PDB structure '7go4'...
# Downloading PDB structure '2of0'...
# Downloading PDB structure '1r6w'...
# Downloading PDB structure '1xug'...
# Downloading PDB structure '1fhd'...
# Downloading PDB structure '7ggg'...
# Downloading PDB structure '3sn8'...
# Downloading PDB structure '7gbi'...
# Downloading PDB structure '7s3k'...
# Downloading PDB structure '7wof'...
# Downloading PDB structure '7vkn'...
# Downloading PDB structure '7gbw'...
# Downloading PDB structure '7fue'...
# Downloading PDB structure '8ov2'...
# Downloading PDB structure '8hje'...
# Downloading PDB structure '3gy5'...
# Downloading PDB structure '5f1g'...
# Downloading PDB structure '3gy2'...
# Downloading PDB structure '7lw4'...
# Downloading PDB structure '4wdb'...
# Downloading PDB structure '3wzk'...
# Downloading PDB structure '1g3e'...
# Downloading PDB structure '3db8'...
# Downloading PDB structure '4ed8'...
# Downloading PDB structure '5rl3'...
# Downloading PDB structure '8b99'...
# Downloading PDB structure '1e36'...
# Downloading PDB structure '5iyt'...
# Downloading PDB structure '7pr8'...
# Downloading PDB structure '3o22'...
# Downloading PDB structure '4mt9'...
# Downloading PDB structure '1btw'...
# Downloading PDB structure '3plp'...
# Downloading PDB structure '5uab'...
# Downloading PDB structure '5rfq'...
# Downloading PDB structure '1v2k'...
# Downloading PDB structure '8ofe'...
# Downloading PDB structure '7bi2'...
# Downloading PDB structure '6zq2'...
# Downloading PDB structure '7n03'...
# Downloading PDB structure '3vv6'...
# Downloading PDB structure '3bm8'...
# Downloading PDB structure '5vzf'...
# Downloading PDB structure '5rxx'...
# Downloading PDB structure '5lcf'...
# Downloading PDB structure '3fv5'...
# Downloading PDB structure '7gcf'...
# Downloading PDB structure '7dw7'...
# Downloading PDB structure '7gon'...
# Downloading PDB structure '5ryj'...
# Downloading PDB structure '3hxw'...
# Downloading PDB structure '3wp6'...
# Downloading PDB structure '5rfw'...
# Downloading PDB structure '6rbu'...
# Downloading PDB structure '1nv4'...
# Downloading PDB structure '3fkt'...
# Downloading PDB structure '8oog'...
# Downloading PDB structure '8qif'...
# Downloading PDB structure '6k9r'...
# Downloading PDB structure '4ui5'...
# Downloading PDB structure '5ret'...
# Downloading PDB structure '7l5f'...
# Downloading PDB structure '7dcz'...
# Downloading PDB structure '4cv8'...
# Downloading PDB structure '4gg5'...
# Downloading PDB structure '5rfh'...
# Downloading PDB structure '6wk6'...
# Downloading PDB structure '5ynb'...
# Downloading PDB structure '2art'...
# Downloading PDB structure '7goh'...
# Downloading PDB structure '1rr6'...
# Downloading PDB structure '8tqj'...
# Downloading PDB structure '4u6a'...
# Downloading PDB structure '6i1i'...
# Downloading PDB structure '6ui2'...
# Downloading PDB structure '3dxy'...
# Downloading PDB structure '7gej'...
# Downloading PDB structure '7gor'...
# Downloading PDB structure '4w5s'...
# Downloading PDB structure '6mq8'...
# Downloading PDB structure '1w55'...
# Downloading PDB structure '5otn'...
# Downloading PDB structure '3smq'...
# Downloading PDB structure '1orh'...
# Downloading PDB structure '2d3l'...
# Downloading PDB structure '1kzl'...
# Downloading PDB structure '7gcq'...
# Downloading PDB structure '1rsd'...
# Downloading PDB structure '8oqc'...
# Downloading PDB structure '5enk'...
# Downloading PDB structure '5oa4'...
# Downloading PDB structure '8jcn'...
# Downloading PDB structure '8pb2'...
# Downloading PDB structure '5hhw'...
# Downloading PDB structure '4hmh'...
# Downloading PDB structure '3c9e'...
# Downloading PDB structure '7f96'...
# Downloading PDB structure '6eqm'...
# Downloading PDB structure '1g3b'...
# Downloading PDB structure '8rfy'...
# Downloading PDB structure '4l7h'...
# Downloading PDB structure '3uaw'...
# Downloading PDB structure '1wpc'...
# Downloading PDB structure '7gey'...
# Downloading PDB structure '3h7d'...
# Downloading PDB structure '6i8m'...
# Downloading PDB structure '6ipj'...
# Downloading PDB structure '8rhr'...
# Downloading PDB structure '4xkx'...
# Downloading PDB structure '7fam'...
# Downloading PDB structure '1n9l'...
# Downloading PDB structure '4r5n'...
# Downloading PDB structure '4bjc'...
# Downloading PDB structure '5tyz'...
# Downloading PDB structure '6ojh'...
# Downloading PDB structure '3plh'...
# Downloading PDB structure '2wab'...
# Downloading PDB structure '4dl3'...
# Downloading PDB structure '4qqn'...
# Downloading PDB structure '7s4b'...
# Downloading PDB structure '4j9o'...
# Downloading PDB structure '8v58'...
# Downloading PDB structure '2oc4'...
# Downloading PDB structure '4qw8'...
# Downloading PDB structure '4o7r'...
# Downloading PDB structure '7m86'...
# Downloading PDB structure '1o32'...
# Downloading PDB structure '6qns'...
# Downloading PDB structure '6qlm'...
# Downloading PDB structure '3lhg'...
# Downloading PDB structure '1nv1'...
# Downloading PDB structure '7gpg'...
# Downloading PDB structure '7ggy'...
# Downloading PDB structure '3p0q'...
# Downloading PDB structure '8d4m'...
# Downloading PDB structure '3n4c'...
# Downloading PDB structure '6t5y'...
# Downloading PDB structure '5kfo'...
# Downloading PDB structure '2a2c'...
# Downloading PDB structure '2hob'...
# Downloading PDB structure '5rfy'...
# Downloading PDB structure '7c8u'...
# Downloading PDB structure '1c1r'...
# Downloading PDB structure '1p4m'...
# Downloading PDB structure '6d1d'...
# Downloading PDB structure '6fcd'...
# Downloading PDB structure '4mlh'...
# Downloading PDB structure '1yqn'...
# Downloading PDB structure '8tqt'...
# Downloading PDB structure '5rwr'...
# Downloading PDB structure '6m7t'...
# Downloading PDB structure '7gdq'...
# Downloading PDB structure '3p0n'...
# Downloading PDB structure '1y3w'...
# Downloading PDB structure '6d1e'...
# Downloading PDB structure '7gf2'...
# Downloading PDB structure '3udq'...
# Downloading PDB structure '8d4k'...
# Downloading PDB structure '4wda'...
# Downloading PDB structure '4bek'...
# Downloading PDB structure '5rep'...
# Downloading PDB structure '6rbz'...
# Downloading PDB structure '3m9n'...
# Downloading PDB structure '1nvs'...
# Downloading PDB structure '5rxg'...
# Downloading PDB structure '7ef8'...
# Downloading PDB structure '3ugj'...
# Downloading PDB structure '6lj6'...
# Downloading PDB structure '5i3w'...
# Downloading PDB structure '8k3x'...
# Downloading PDB structure '4xxs'...
# Downloading PDB structure '6vcy'...
# Downloading PDB structure '6dmi'...
# Downloading PDB structure '7tvs'...
# Downloading PDB structure '1o4h'...
# Downloading PDB structure '1c2k'...
# Downloading PDB structure '1sjw'...
# Downloading PDB structure '4d2r'...
# Downloading PDB structure '6dtn'...
# Downloading PDB structure '6do9'...
# Downloading PDB structure '8v7a'...
# Downloading PDB structure '7esc'...
# Downloading PDB structure '5tyb'...
# Downloading PDB structure '7vcp'...
# Downloading PDB structure '4ect'...
# Downloading PDB structure '5efw'...
# Downloading PDB structure '6m5p'...
# Downloading PDB structure '4a1t'...
# Downloading PDB structure '4r7i'...
# Downloading PDB structure '7lfu'...
# Downloading PDB structure '8qin'...
# Downloading PDB structure '7ltn'...
# Downloading PDB structure '5al5'...
# Downloading PDB structure '3q46'...
# Downloading PDB structure '5r81'...
# Downloading PDB structure '7ei2'...
# Downloading PDB structure '6vf2'...
# Downloading PDB structure '4ux4'...
# Downloading PDB structure '4nq6'...
# Downloading PDB structure '6vf1'...
# Downloading PDB structure '1xxn'...
# Downloading PDB structure '1er8'...
# Downloading PDB structure '4b00'...
# Downloading PDB structure '6rbt'...
# Downloading PDB structure '8fiv'...
# Downloading PDB structure '5xzg'...
# Downloading PDB structure '1f0t'...
# Downloading PDB structure '4l2f'...
# Downloading PDB structure '4dus'...
# Downloading PDB structure '7rn0'...
# Downloading PDB structure '5fpf'...
# Downloading PDB structure '6hf5'...
# Downloading PDB structure '4yoq'...
# Downloading PDB structure '3dha'...
# Downloading PDB structure '1zys'...
# Downloading PDB structure '1oho'...
# Downloading PDB structure '6hle'...
# Downloading PDB structure '3v7u'...
# Downloading PDB structure '8pgb'...
# Downloading PDB structure '1gim'...
# Downloading PDB structure '7gb5'...
# Downloading PDB structure '1xbc'...
# Downloading PDB structure '8pah'...
# Downloading PDB structure '1f9v'...
# Downloading PDB structure '7ggj'...
# Downloading PDB structure '5adr'...
# Downloading PDB structure '1o3e'...
# Downloading PDB structure '7gb9'...
# Downloading PDB structure '8b4t'...
# Downloading PDB structure '7gf8'...
# Downloading PDB structure '3hy8'...
# Downloading PDB structure '2va6'...
# Downloading PDB structure '5rgu'...
# Downloading PDB structure '3nhx'...
# Downloading PDB structure '7fan'...
# Downloading PDB structure '4p1h'...
# Downloading PDB structure '5vze'...
# Downloading PDB structure '4aig'...
# Downloading PDB structure '6rne'...
# Downloading PDB structure '6yz1'...
# Downloading PDB structure '7m7o'...
# Downloading PDB structure '4dae'...
# Downloading PDB structure '6j4p'...
# Downloading PDB structure '8pgk'...
# Downloading PDB structure '4imn'...
# Downloading PDB structure '7ge5'...
# Downloading PDB structure '1ql9'...
# Downloading PDB structure '2xlq'...
# Downloading PDB structure '7fuq'...
# Downloading PDB structure '1y3y'...
# Downloading PDB structure '4emd'...
# Downloading PDB structure '1ri4'...
# Downloading PDB structure '1u9w'...
# Downloading PDB structure '5rg3'...
# Downloading PDB structure '7o46'...
# Downloading PDB structure '8pgo'...
# Downloading PDB structure '1yw9'...
# Downloading PDB structure '7gc8'...
# Downloading PDB structure '3dz6'...
# Downloading PDB structure '5dpa'...
# Downloading PDB structure '7p0g'...
# Downloading PDB structure '7jyq'...
# Downloading PDB structure '1o2q'...
# Downloading PDB structure '1s6f'...
# Downloading PDB structure '4j1c'...
# Downloading PDB structure '2fqf'...
# Downloading PDB structure '6j7b'...
# Downloading PDB structure '7nh7'...
# Downloading PDB structure '4b05'...
# Downloading PDB structure '4itn'...
# Downloading PDB structure '7oo9'...
# Downloading PDB structure '7gg2'...
# Downloading PDB structure '8v7i'...
# Downloading PDB structure '4uvt'...
# Downloading PDB structure '6lbl'...
# Downloading PDB structure '6au3'...
# Downloading PDB structure '8b1w'...
# Downloading PDB structure '5re9'...
# Downloading PDB structure '3mr2'...
# Downloading PDB structure '1ito'...
# Downloading PDB structure '8v7g'...
# Downloading PDB structure '4xeb'...
# Downloading PDB structure '7ghj'...
# Downloading PDB structure '7cjm'...
# Downloading PDB structure '7sda'...
# Downloading PDB structure '3m6p'...
# Downloading PDB structure '2oaz'...
# Downloading PDB structure '7gez'...
# Downloading PDB structure '1ori'...
# Downloading PDB structure '7ggi'...
# Downloading PDB structure '1fzz'...
# Downloading PDB structure '1bib'...
# Downloading PDB structure '8h9c'...
# Downloading PDB structure '8dwd'...
# Downloading PDB structure '5tol'...
# Downloading PDB structure '3v3m'...
# Downloading PDB structure '1thy'...
# Downloading PDB structure '6mxo'...
# Downloading PDB structure '3uh2'...
# Downloading PDB structure '7mlf'...
# Downloading PDB structure '5oc7'...
# Downloading PDB structure '5kfn'...
# Downloading PDB structure '1q2q'...
# Downloading PDB structure '6doe'...
# Downloading PDB structure '4azy'...
# Downloading PDB structure '6k30'...
# Downloading PDB structure '5oa7'...
# Downloading PDB structure '3ind'...
# Downloading PDB structure '2ydc'...
# Downloading PDB structure '7ghi'...
# Downloading PDB structure '4ruc'...
# Downloading PDB structure '2ohq'...
# Downloading PDB structure '3exo'...
# Downloading PDB structure '2r7n'...
# Downloading PDB structure '7gbe'...
# Downloading PDB structure '1rs4'...
# Downloading PDB structure '5aku'...
# Downloading PDB structure '6rn9'...
# Downloading PDB structure '6wid'...
# Downloading PDB structure '5rw4'...
# Downloading PDB structure '8xar'...
# Downloading PDB structure '5mgh'...
# Downloading PDB structure '5yas'...
# Downloading PDB structure '6jt3'...
# Downloading PDB structure '3d62'...
# Downloading PDB structure '7dhj'...
# Downloading PDB structure '5rh0'...
# Downloading PDB structure '2v0w'...
# Downloading PDB structure '8uuw'...
# Downloading PDB structure '4i0f'...
# Downloading PDB structure '5rw5'...
# Downloading PDB structure '3pw5'...
# Downloading PDB structure '4pax'...
# Downloading PDB structure '7gf0'...
# Downloading PDB structure '8b4w'...
# Downloading PDB structure '6rsa'...
# Downloading PDB structure '4c81'...
# Downloading PDB structure '7b1q'...
# Downloading PDB structure '2i2b'...
# Downloading PDB structure '1u5a'...
# Downloading PDB structure '1y11'...
# Downloading PDB structure '5rx1'...
# Downloading PDB structure '7gcu'...
# Downloading PDB structure '2ypc'...
# Downloading PDB structure '6occ'...
# Downloading PDB structure '1tdc'...
# Downloading PDB structure '1c1s'...
# Downloading PDB structure '7gd2'...
# Downloading PDB structure '4rrr'...
# Downloading PDB structure '1pa9'...
# Downloading PDB structure '5adt'...
# Downloading PDB structure '3im2'...
# Downloading PDB structure '8bje'...
# Downloading PDB structure '7gbn'...
# Downloading PDB structure '7gol'...
# Downloading PDB structure '4qck'...
# Downloading PDB structure '3o1g'...
# Downloading PDB structure '5rgl'...
# Downloading PDB structure '4gbw'...
# Downloading PDB structure '7lcs'...
# Downloading PDB structure '6h1v'...
# Downloading PDB structure '7dyz'...
# Downloading PDB structure '4c1h'...
# Downloading PDB structure '1eae'...
# Downloading PDB structure '5kt4'...
# Downloading PDB structure '8bk5'...
# Downloading PDB structure '7qbo'...
# Downloading PDB structure '5kq8'...
# Downloading PDB structure '6t85'...
# Downloading PDB structure '5kff'...
# Downloading PDB structure '2zox'...
# Downloading PDB structure '1eb2'...
# Downloading PDB structure '4lc7'...
# Downloading PDB structure '5cx0'...
# Downloading PDB structure '8gvd'...
# Downloading PDB structure '6m9h'...
# Downloading PDB structure '4rd0'...
# Downloading PDB structure '4fri'...
# Downloading PDB structure '5ij6'...
# Downloading PDB structure '5win'...
# Downloading PDB structure '1nuz'...
# Downloading PDB structure '3eig'...
# Downloading PDB structure '4u32'...
# Downloading PDB structure '6ksc'...
# Downloading PDB structure '6itd'...
# Downloading PDB structure '5rgm'...
# Downloading PDB structure '7gfp'...
# Downloading PDB structure '2xyv'...
# Downloading PDB structure '8il9'...
# Downloading PDB structure '2rdn'...
# Downloading PDB structure '1o2v'...
# Downloading PDB structure '3pyg'...
# Downloading PDB structure '6icl'...
# Downloading PDB structure '6lj2'...
# Downloading PDB structure '4ucr'...
# Downloading PDB structure '6ttc'...
# Downloading PDB structure '2c5s'...
# Downloading PDB structure '5o7e'...
# Downloading PDB structure '5xzb'...
# Downloading PDB structure '5kqf'...
# Downloading PDB structure '6xsc'...
# Downloading PDB structure '8ans'...
# Downloading PDB structure '4j1e'...
# Downloading PDB structure '2zdn'...
# Downloading PDB structure '8jcm'...
# Downloading PDB structure '7gdk'...
# Downloading PDB structure '1elg'...
# Downloading PDB structure '7kt6'...
# Downloading PDB structure '5a56'...
# Downloading PDB structure '4hkn'...
# Downloading PDB structure '7gpq'...
# Downloading PDB structure '4da0'...
# Downloading PDB structure '8ojb'...
# Downloading PDB structure '8pod'...
# Downloading PDB structure '2v35'...
# Downloading PDB structure '5rgg'...
# Downloading PDB structure '4wdf'...
# Downloading PDB structure '8bcy'...
# Downloading PDB structure '8qrj'...
# Downloading PDB structure '8pge'...
# Downloading PDB structure '5gjp'...
# Downloading PDB structure '7kyu'...
# Downloading PDB structure '5hjm'...
# Downloading PDB structure '7gc9'...
# Downloading PDB structure '3wue'...
# Downloading PDB structure '3mz5'...
# Downloading PDB structure '6eqv'...
# Downloading PDB structure '5fpg'...
# Downloading PDB structure '2obv'...
# Downloading PDB structure '6qlx'...
# Downloading PDB structure '7sfh'...
# Downloading PDB structure '4eeu'...
# Downloading PDB structure '5kfz'...
# Downloading PDB structure '7gfo'...
# Downloading PDB structure '7m90'...
# Downloading PDB structure '7ggn'...
# Downloading PDB structure '5eub'...
# Downloading PDB structure '5kfr'...
# Downloading PDB structure '7gdm'...
# Downloading PDB structure '5dcz'...
# Downloading PDB structure '2hl1'...
# Downloading PDB structure '3vv7'...
# Downloading PDB structure '3gch'...
# Downloading PDB structure '2p02'...
# Downloading PDB structure '9boo'...
# Downloading PDB structure '5rxk'...
# Downloading PDB structure '5dp5'...
# Downloading PDB structure '3rq4'...
# Downloading PDB structure '3nk8'...
# Downloading PDB structure '6vf6'...
# Downloading PDB structure '3zze'...
# Downloading PDB structure '5red'...
# Downloading PDB structure '1o3k'...
# Downloading PDB structure '6q0c'...
# Downloading PDB structure '8s63'...
# Downloading PDB structure '2vj9'...
# Downloading PDB structure '2oc9'...
# Downloading PDB structure '7lmd'...
# Downloading PDB structure '8b77'...
# Downloading PDB structure '7geg'...
# Downloading PDB structure '1ej0'...
# Downloading PDB structure '3pwc'...
# Downloading PDB structure '3uqv'...
# Downloading PDB structure '2g89'...
# Downloading PDB structure '6ipi'...
# Downloading PDB structure '7ksu'...
# Downloading PDB structure '4da6'...
# Downloading PDB structure '5ke2'...
# Downloading PDB structure '3v1m'...
# Downloading PDB structure '4bsq'...
# Downloading PDB structure '4l23'...
# Downloading PDB structure '4j0v'...
# Downloading PDB structure '5vzi'...
# Downloading PDB structure '1y5u'...
# Downloading PDB structure '3aat'...
# Downloading PDB structure '2va7'...
# Downloading PDB structure '5wp4'...
# Downloading PDB structure '3byn'...
# Downloading PDB structure '3vw8'...
# Downloading PDB structure '7d8f'...
# Downloading PDB structure '5kr8'...
# Downloading PDB structure '6vcx'...
# Downloading PDB structure '4n00'...
# Downloading PDB structure '5ubt'...
# Downloading PDB structure '4b0q'...
# Downloading PDB structure '3gy8'...
# Downloading PDB structure '2ai1'...
# Downloading PDB structure '4hki'...
# Downloading PDB structure '7gpo'...
# Downloading PDB structure '7kri'...
# Downloading PDB structure '5rgj'...
# Downloading PDB structure '1ql7'...
# Downloading PDB structure '3igb'...
# Downloading PDB structure '8iyv'...
# Downloading PDB structure '2imw'...
# Downloading PDB structure '2wgj'...
# Downloading PDB structure '3ld4'...
# Downloading PDB structure '3bgs'...
# Downloading PDB structure '8ph0'...
# Downloading PDB structure '5mae'...
# Downloading PDB structure '5rg0'...
# Downloading PDB structure '8fo0'...
# Downloading PDB structure '3o19'...
# Downloading PDB structure '5rfn'...
# Downloading PDB structure '5rh3'...
# Downloading PDB structure '7bhs'...
# Downloading PDB structure '5wik'...
# Downloading PDB structure '5rf8'...
# Downloading PDB structure '9f6i'...
# Downloading PDB structure '3sw8'...
# Downloading PDB structure '7kkp'...
# Downloading PDB structure '5lca'...
# Downloading PDB structure '8evf'...
# Downloading PDB structure '6uad'...
# Downloading PDB structure '7goa'...
# Downloading PDB structure '5ryd'...
# Downloading PDB structure '6lj5'...
# Downloading PDB structure '5ut4'...
# Downloading PDB structure '2g81'...
# Downloading PDB structure '4i12'...
# Downloading PDB structure '3rtn'...
# Downloading PDB structure '3udr'...
# Downloading PDB structure '7m7q'...
# Downloading PDB structure '2cgj'...
# Downloading PDB structure '7ger'...
# Downloading PDB structure '1xuk'...
# Downloading PDB structure '1o39'...
# Downloading PDB structure '6m7o'...
# Downloading PDB structure '5rh2'...
# Downloading PDB structure '2zjj'...
# Downloading PDB structure '7ggc'...
# Downloading PDB structure '4o7t'...
# Downloading PDB structure '8gml'...
# Downloading PDB structure '7goo'...
# Downloading PDB structure '4qqk'...
# Downloading PDB structure '8s0w'...
# Downloading PDB structure '6u7t'...
# Downloading PDB structure '5twp'...
# Downloading PDB structure '4exg'...
# Downloading PDB structure '3m9m'...
# Downloading PDB structure '6b6p'...
# Downloading PDB structure '5kfm'...
# Downloading PDB structure '7gc7'...
# Downloading PDB structure '6w3k'...
# Downloading PDB structure '7sgw'...
# Downloading PDB structure '7gh7'...
# Downloading PDB structure '3ooz'...
# Downloading PDB structure '4ken'...
# Downloading PDB structure '7ddc'...
# Downloading PDB structure '6rn7'...
# Downloading PDB structure '2rds'...
# Downloading PDB structure '1d5r'...
# Downloading PDB structure '3bk8'...
# Downloading PDB structure '6rbp'...
# Downloading PDB structure '7gbj'...
# Downloading PDB structure '4px6'...
# Downloading PDB structure '7ggr'...
# Downloading PDB structure '4gww'...
# Downloading PDB structure '4ecu'...
# Downloading PDB structure '8gvy'...
# Downloading PDB structure '2ew5'...
# Downloading PDB structure '4y9w'...
# Downloading PDB structure '3h9r'...
# Downloading PDB structure '7lm2'...
# Downloading PDB structure '1ucc'...
# Downloading PDB structure '1o3b'...
# Downloading PDB structure '5mbw'...
# Downloading PDB structure '5xhr'...
# Downloading PDB structure '4i0t'...
# Downloading PDB structure '7s3s'...
# Downloading PDB structure '4pzx'...
# Downloading PDB structure '1tpp'...
# Downloading PDB structure '3av6'...
# Downloading PDB structure '8sbc'...
# Downloading PDB structure '5a89'...
# Downloading PDB structure '6oha'...
# Downloading PDB structure '1k1i'...
# Downloading PDB structure '1nv2'...
# Downloading PDB structure '2yp0'...
# Downloading PDB structure '8rfl'...
# Downloading PDB structure '7fu8'...
# Downloading PDB structure '6rbs'...
# Downloading PDB structure '5rwc'...
# Downloading PDB structure '8pg4'...
# Downloading PDB structure '7a15'...
# Downloading PDB structure '3o0u'...
# Downloading PDB structure '2er6'...
# Downloading PDB structure '7gh6'...
# Downloading PDB structure '5rwe'...
# Downloading PDB structure '1nrr'...
# Downloading PDB structure '4ym9'...
# Downloading PDB structure '1yw7'...
# Downloading PDB structure '6ak6'...
# Downloading PDB structure '8oqg'...
# Downloading PDB structure '5rev'...
# Downloading PDB structure '5ya5'...
# Downloading PDB structure '4hzt'...
# Downloading PDB structure '7gfs'...
# Downloading PDB structure '1j01'...
# Downloading PDB structure '2b0f'...
# Downloading PDB structure '6tm9'...
# Downloading PDB structure '5ref'...
# Downloading PDB structure '1c5i'...
# Downloading PDB structure '7geb'...
# Downloading PDB structure '1az8'...
# Downloading PDB structure '5wkk'...
# Downloading PDB structure '5m9o'...
# Downloading PDB structure '7m7u'...
# Downloading PDB structure '8cgc'...
# Downloading PDB structure '4f6z'...
# Downloading PDB structure '2a0w'...
# Downloading PDB structure '7d5u'...
# Downloading PDB structure '3cxq'...
# Downloading PDB structure '6ia3'...
# Downloading PDB structure '1rar'...
# Downloading PDB structure '1o2u'...
# Downloading PDB structure '7gdz'...
# Downloading PDB structure '1e37'...
# Downloading PDB structure '1esb'...
# Downloading PDB structure '7gg0'...
# Downloading PDB structure '5rwm'...
# Downloading PDB structure '2agg'...
# Downloading PDB structure '4hef'...
# Downloading PDB structure '8jig'...
# Downloading PDB structure '5kfi'...
# Downloading PDB structure '1asb'...
# Downloading PDB structure '2gz8'...
# Downloading PDB structure '1b8n'...
# Downloading PDB structure '5rh9'...
# Downloading PDB structure '6o47'...
# Downloading PDB structure '3ht5'...
# Downloading PDB structure '8sdr'...
# Downloading PDB structure '4o7l'...
# Downloading PDB structure '5nwc'...
# Downloading PDB structure '1b6a'...
# Downloading PDB structure '4uvs'...
# Downloading PDB structure '8pgl'...
# Downloading PDB structure '2efj'...
# Downloading PDB structure '1o35'...
# Downloading PDB structure '8jbw'...
# Downloading PDB structure '5wim'...
# Downloading PDB structure '2vqd'...
# Downloading PDB structure '7ggm'...
# Downloading PDB structure '8ty3'...
# Downloading PDB structure '7d5b'...
# Downloading PDB structure '6h3k'...
# Downloading PDB structure '5lz2'...
# Downloading PDB structure '2ype'...
# Downloading PDB structure '3v12'...
# Downloading PDB structure '3dhc'...
# Downloading PDB structure '7m87'...
# Downloading PDB structure '1owk'...
# Downloading PDB structure '7gbz'...
# Downloading PDB structure '2ick'...
# Downloading PDB structure '5l1l'...
# Downloading PDB structure '6rc3'...
# Downloading PDB structure '3plk'...
# Downloading PDB structure '8eve'...
# Downloading PDB structure '8b4v'...
# Downloading PDB structure '6rc2'...
# Downloading PDB structure '2auz'...
# Downloading PDB structure '5ikw'...
# Downloading PDB structure '1ore'...
# Downloading PDB structure '2qy2'...
# Downloading PDB structure '7geh'...
# Downloading PDB structure '8pa5'...
# Downloading PDB structure '3pfg'...
# Downloading PDB structure '4ez8'...
# Downloading PDB structure '6tht'...
# Downloading PDB structure '3awn'...
# Downloading PDB structure '6sde'...
# Downloading PDB structure '7gbp'...
# Downloading PDB structure '5vzc'...
# Downloading PDB structure '8gqt'...
# Downloading PDB structure '5xze'...
# Downloading PDB structure '1auj'...
# Downloading PDB structure '1cla'...
# Downloading PDB structure '4ufy'...
# Downloading PDB structure '6lj0'...
# Downloading PDB structure '4bjb'...
# Downloading PDB structure '7nmk'...
# Downloading PDB structure '4yph'...
# Downloading PDB structure '4nz7'...
# Downloading PDB structure '3v80'...
# Downloading PDB structure '7p0d'...
# Downloading PDB structure '6nrf'...
# Downloading PDB structure '5enl'...
# Downloading PDB structure '5rgs'...
# Downloading PDB structure '7bqy'...
# Downloading PDB structure '8dvp'...
# Downloading PDB structure '7gg9'...
# Downloading PDB structure '7aqi'...
# Downloading PDB structure '6h00'...
# Downloading PDB structure '4i5p'...
# Downloading PDB structure '6jfs'...
# Downloading PDB structure '1f0u'...
# Downloading PDB structure '8acl'...
# Downloading PDB structure '1o2k'...
# Downloading PDB structure '1ppx'...
# Downloading PDB structure '2dcb'...
# Downloading PDB structure '5kfd'...
# Downloading PDB structure '5lyx'...
# Downloading PDB structure '1e34'...
# Downloading PDB structure '7gq9'...
# Downloading PDB structure '8fn3'...
# Downloading PDB structure '1nb9'...
# Downloading PDB structure '7rme'...
# Downloading PDB structure '4l87'...
# Downloading PDB structure '3dkf'...
# Downloading PDB structure '4oel'...
# Downloading PDB structure '4ecw'...
# Downloading PDB structure '4ed0'...
# Downloading PDB structure '5d6e'...
# Downloading PDB structure '3wzj'...
# Downloading PDB structure '4ehy'...
# Downloading PDB structure '6y7r'...
# Downloading PDB structure '2zjm'...
# Downloading PDB structure '3tka'...
# Downloading PDB structure '4d17'...
# Downloading PDB structure '3thb'...
# Downloading PDB structure '4e9b'...
# Downloading PDB structure '1ele'...
# Downloading PDB structure '1kkf'...
# Downloading PDB structure '1dit'...
# Downloading PDB structure '4m0a'...
# Downloading PDB structure '1drf'...
# Downloading PDB structure '1ms6'...
# Downloading PDB structure '1k1o'...
# Downloading PDB structure '2yrx'...
# Downloading PDB structure '1i9g'...
# Downloading PDB structure '3udn'...
# Downloading PDB structure '1e35'...
# Downloading PDB structure '1mdl'...
# Downloading PDB structure '2hkj'...
# Downloading PDB structure '4u9s'...
# Downloading PDB structure '2wao'...
# Downloading PDB structure '1i6t'...
# Downloading PDB structure '3uh0'...
# Downloading PDB structure '2v13'...
# Downloading PDB structure '3ej0'...
# Downloading PDB structure '2o90'...
# Downloading PDB structure '3udh'...
# Downloading PDB structure '1aec'...
# Downloading PDB structure '3pkt'...
# Downloading PDB structure '1asd'...
# Downloading PDB structure '4rch'...
# Downloading PDB structure '5kfx'...
# Downloading PDB structure '3mhk'...
# Downloading PDB structure '4x6j'...
# Downloading PDB structure '3udk'...
# Downloading PDB structure '1c1p'...
# Downloading PDB structure '4n79'...
# Downloading PDB structure '8p93'...
# Downloading PDB structure '3s3v'...
# Downloading PDB structure '5rfv'...
# Downloading PDB structure '5rhd'...
# Downloading PDB structure '5rft'...
# Downloading PDB structure '6qen'...
# Downloading PDB structure '6qcb'...
# Downloading PDB structure '4er2'...
# Downloading PDB structure '6rg7'...
# Downloading PDB structure '5rgx'...
# Downloading PDB structure '5rf6'...
# Downloading PDB structure '5rgi'...
# Downloading PDB structure '6dpf'...
# Downloading PDB structure '3plj'...
# Downloading PDB structure '4hlh'...
# Downloading PDB structure '4qwd'...
# Downloading PDB structure '4kzu'...
# Downloading PDB structure '1ksz'...
# Downloading PDB structure '5reu'...
# Downloading PDB structure '6bpi'...
# Downloading PDB structure '5mnq'...
# Downloading PDB structure '6gpu'...
# Downloading PDB structure '4hc4'...
# Downloading PDB structure '6a9a'...
# Downloading PDB structure '5d6f'...
# Downloading PDB structure '3l38'...
# Downloading PDB structure '5tyd'...
# Downloading PDB structure '3rth'...
# Downloading PDB structure '4rce'...
# Downloading PDB structure '5ree'...
# Downloading PDB structure '5rfm'...
# Downloading PDB structure '7gg1'...
# Downloading PDB structure '2ga2'...
# Downloading PDB structure '7gfc'...
# Downloading PDB structure '4qw9'...
# Downloading PDB structure '3zz7'...
# Downloading PDB structure '7gp3'...
# Downloading PDB structure '7gge'...
# Downloading PDB structure '1knw'...
# Downloading PDB structure '7p2g'...
# Downloading PDB structure '1b8o'...
# Downloading PDB structure '3gv7'...
# Downloading PDB structure '5ehy'...
# Downloading PDB structure '6ywh'...
# Downloading PDB structure '4buu'...
# Downloading PDB structure '5rgr'...
# Downloading PDB structure '7qbn'...
# Downloading PDB structure '4r1v'...
# Downloading PDB structure '3cuf'...
# Downloading PDB structure '5n95'...
# Downloading PDB structure '4lmd'...
# Downloading PDB structure '7gqh'...
# Downloading PDB structure '2z6c'...
# Downloading PDB structure '1efy'...
# Downloading PDB structure '3pd4'...
# Downloading PDB structure '7ggh'...
# Downloading PDB structure '1jg1'...
# Downloading PDB structure '7qbb'...
# Downloading PDB structure '5kfe'...
# Downloading PDB structure '1iht'...
# Downloading PDB structure '2plx'...
# Downloading PDB structure '1c2d'...
# Downloading PDB structure '3vv8'...
# Downloading PDB structure '3teg'...
# Downloading PDB structure '4jp9'...
# Downloading PDB structure '7krx'...
# Downloading PDB structure '7o22'...
# Downloading PDB structure '7gp0'...
# Downloading PDB structure '4abg'...
# Downloading PDB structure '1ql8'...
# Downloading PDB structure '7o20'...
# Downloading PDB structure '5a59'...
# Downloading PDB structure '4he2'...
# Downloading PDB structure '5wil'...
# Downloading PDB structure '7gqe'...
# Downloading PDB structure '6hhz'...
# Downloading PDB structure '3ru1'...
# Downloading PDB structure '7ghe'...
# Downloading PDB structure '5rh8'...
# Downloading PDB structure '2yq9'...
# Downloading PDB structure '6rau'...
# Downloading PDB structure '7ggt'...
# Downloading PDB structure '5rhe'...
# Downloading PDB structure '5rwl'...
# Downloading PDB structure '1x54'...
# Downloading PDB structure '7gfv'...
# Downloading PDB structure '7aol'...
# Downloading PDB structure '4cla'...
# Downloading PDB structure '7e8z'...
# Downloading PDB structure '7dv0'...
# Downloading PDB structure '5yn8'...
# Downloading PDB structure '6ipd'...
# Downloading PDB structure '5ggb'...
# Downloading PDB structure '4ru9'...
# Downloading PDB structure '5rw3'...
# Downloading PDB structure '4je7'...
# Downloading PDB structure '5rwy'...
# Downloading PDB structure '5rh7'...
# Downloading PDB structure '7duy'...
# Downloading PDB structure '2v1b'...
# Downloading PDB structure '2uyt'...
# Downloading PDB structure '4da8'...
# Downloading PDB structure '1pie'...
# Downloading PDB structure '6yw4'...
# Downloading PDB structure '7gga'...
# Downloading PDB structure '4wf0'...
# Downloading PDB structure '6ic6'...
# Downloading PDB structure '4w9w'...
# Downloading PDB structure '7jn2'...
# Downloading PDB structure '7m7r'...
# Downloading PDB structure '1cef'...
# Downloading PDB structure '6wtk'...
# Downloading PDB structure '3wb5'...
# Downloading PDB structure '8pgc'...
# Downloading PDB structure '6ipg'...
# Downloading PDB structure '3hfv'...
# Downloading PDB structure '8qit'...
# Downloading PDB structure '6ywi'...
# ...
# Downloading PDB structure '5smm'...
# Downloading PDB structure '6p1t'...
# Downloading PDB structure '4o7z'...
# Downloading PDB structure '7get'...
# Downloading PDB structure '5rew'...
# Downloading PDB structure '4pr8'...
# Downloading PDB structure '5rxq'...
# Downloading PDB structure '8b9e'...
# Downloading PDB structure '3u9y'...
# Downloading PDB structure '5mxr'...
# Downloading PDB structure '3zvb'...
# Downloading PDB structure '2r42'...
# Downloading PDB structure '4li7'...
# Downloading PDB structure '5uyu'...
# Downloading PDB structure '3pyh'...
# Downloading PDB structure '6ywg'...
# Downloading PDB structure '2pqt'...
# Downloading PDB structure '1o3n'...
# Downloading PDB structure '1u4s'...
# Downloading PDB structure '2hl2'...
# Downloading PDB structure '5rfj'...
# Downloading PDB structure '3rsx'...
# Downloading PDB structure '8dw0'...
# Downloading PDB structure '3pk4'...
# Downloading PDB structure '4abh'...
# Downloading PDB structure '7f9s'...
# Downloading PDB structure '6yd7'...
# Downloading PDB structure '7n8c'...
# Downloading PDB structure '4bua'...
# Downloading PDB structure '4n3r'...
# Downloading PDB structure '7gec'...
# Downloading PDB structure '7qbl'...
# Downloading PDB structure '5ry7'...
# Downloading PDB structure '7gf3'...
# Downloading PDB structure '7qt6'...
# Downloading PDB structure '1o2h'...
# Downloading PDB structure '3udp'...
# Downloading PDB structure '5cls'...
# Downloading PDB structure '2pes'...
# Downloading PDB structure '7b1p'...
# Downloading PDB structure '8oto'...
# Downloading PDB structure '2aex'...
# Downloading PDB structure '7gdo'...
# Downloading PDB structure '5mgu'...
# Downloading PDB structure '3lkm'...
# Downloading PDB structure '5vz9'...
# Downloading PDB structure '4k4e'...
# Downloading PDB structure '1eyi'...
# Downloading PDB structure '5use'...
# Downloading PDB structure '7gh3'...
# Downloading PDB structure '5nwd'...
# Downloading PDB structure '1j17'...
# Downloading PDB structure '5rx7'...
# Downloading PDB structure '4uhg'...
# Downloading PDB structure '8dvh'...
# Downloading PDB structure '4ecr'...
# Downloading PDB structure '7kdb'...
# Downloading PDB structure '7gdh'...
# Downloading PDB structure '4yr0'...
# Downloading PDB structure '2h6t'...
# Downloading PDB structure '2zka'...
# Downloading PDB structure '3pjk'...
# Downloading PDB structure '6lny'...
# Downloading PDB structure '6jt4'...
# Downloading PDB structure '6yrp'...
# Downloading PDB structure '7c2j'...
# Downloading PDB structure '2oj9'...
# Downloading PDB structure '4i0j'...
# Downloading PDB structure '8hy2'...
# Downloading PDB structure '7gbr'...
# Downloading PDB structure '5cwx'...
# Downloading PDB structure '6rc6'...
# Downloading PDB structure '5cvk'...
# Downloading PDB structure '7gbu'...
# Downloading PDB structure '1o34'...
# Downloading PDB structure '1o30'...
# Downloading PDB structure '7lcp'...
# Downloading PDB structure '4b1e'...
# Downloading PDB structure '9cmu'...
# Downloading PDB structure '7fuo'...
# Downloading PDB structure '2j66'...
# Downloading PDB structure '7d3i'...
# Downloading PDB structure '8d3u'...
# Downloading PDB structure '5zj2'...
# Downloading PDB structure '6kro'...
# Downloading PDB structure '5kfa'...
# Downloading PDB structure '7z6k'...
# Downloading PDB structure '1qr3'...
# Downloading PDB structure '3l9g'...
# Downloading PDB structure '4w6e'...
# Downloading PDB structure '6qqi'...
# Downloading PDB structure '6rbo'...
# Downloading PDB structure '7d36'...
# Downloading PDB structure '4dmx'...
# Downloading PDB structure '1rnm'...
# Downloading PDB structure '6pl8'...
# Downloading PDB structure '5nsp'...
# Downloading PDB structure '1ikg'...
# Downloading PDB structure '5ugi'...
# Downloading PDB structure '4ywr'...
# Downloading PDB structure '7wo2'...
# Downloading PDB structure '5aeh'...
# Downloading PDB structure '6a84'...
# Downloading PDB structure '4m51'...
# Downloading PDB structure '8t5n'...
# Downloading PDB structure '4l31'...
# Downloading PDB structure '2eju'...
# Downloading PDB structure '5rxo'...
# Downloading PDB structure '8xb0'...
# Downloading PDB structure '6yx4'...
# Downloading PDB structure '3e3u'...
# Downloading PDB structure '1h0p'...
# Downloading PDB structure '6brw'...
# Downloading PDB structure '2zyl'...
# Downloading PDB structure '1yyy'...
# Downloading PDB structure '1g3c'...
# Downloading PDB structure '2qgh'...
# Downloading PDB structure '7q0w'...
# Downloading PDB structure '9gny'...
# Downloading PDB structure '5zio'...
# Downloading PDB structure '4ecx'...
# Downloading PDB structure '1fh9'...
# Downloading PDB structure '7fuk'...
# Downloading PDB structure '7gfu'...
# Downloading PDB structure '7ti1'...
# Downloading PDB structure '2ej9'...
# Downloading PDB structure '4x2l'...
# Downloading PDB structure '5rx8'...
# Downloading PDB structure '7fu2'...
# Downloading PDB structure '4ui3'...
# Downloading PDB structure '7gq0'...
# Downloading PDB structure '1rry'...
# Downloading PDB structure '5yn6'...
# Downloading PDB structure '6pq8'...
# Downloading PDB structure '7gb7'...
# Downloading PDB structure '8p9q'...
# Downloading PDB structure '8ph1'...
# Downloading PDB structure '8h0t'...
# Downloading PDB structure '1o3h'...
# Downloading PDB structure '5rxd'...
# Downloading PDB structure '8ba2'...
# Downloading PDB structure '5ei8'...
# Downloading PDB structure '3i8d'...
# Downloading PDB structure '7koj'...
# Downloading PDB structure '1ogz'...
# Downloading PDB structure '3a27'...
# Downloading PDB structure '8i11'...
# Downloading PDB structure '1u71'...
# Downloading PDB structure '7nrb'...
# Downloading PDB structure '5hzm'...
# Downloading PDB structure '3ik0'...
# Downloading PDB structure '5b1k'...
# Downloading PDB structure '7gqd'...
# Downloading PDB structure '3bnz'...
# Downloading PDB structure '3sbl'...
# Downloading PDB structure '7n4n'...
# Downloading PDB structure '4ie5'...
# Downloading PDB structure '7gqg'...
# Downloading PDB structure '7jyo'...
# Downloading PDB structure '1fh8'...
# Downloading PDB structure '5k55'...
# Downloading PDB structure '5ae0'...
# Downloading PDB structure '4j3l'...
# Downloading PDB structure '6tmc'...
# Downloading PDB structure '6qqk'...
# Downloading PDB structure '7bhx'...
# Downloading PDB structure '5dax'...
# Downloading PDB structure '7dgf'...
# Downloading PDB structure '8g2f'...
# Downloading PDB structure '7ged'...
# Downloading PDB structure '5zrh'...
# Downloading PDB structure '4bud'...
# Downloading PDB structure '6doc'...
# Downloading PDB structure '6zfk'...
# Downloading PDB structure '7jiv'...
# Downloading PDB structure '6yx6'...
# Downloading PDB structure '7qjp'...
# Downloading PDB structure '5l9z'...
# Downloading PDB structure '7chv'...
# Downloading PDB structure '5zrg'...
# Downloading PDB structure '7ktg'...
# Downloading PDB structure '5v6a'...
# Downloading PDB structure '5t1w'...
# Downloading PDB structure '9grq'...
# Downloading PDB structure '8rfx'...
# Downloading PDB structure '1rt9'...
# Downloading PDB structure '7awr'...
# Downloading PDB structure '3np8'...
# Downloading PDB structure '8g2h'...
# Downloading PDB structure '5ko6'...
# Downloading PDB structure '3kwb'...
# Downloading PDB structure '4zn5'...
# Downloading PDB structure '7ghf'...
# Downloading PDB structure '5rxs'...
# Downloading PDB structure '6p9v'...
# Downloading PDB structure '4qdc'...
# Downloading PDB structure '1nh8'...
# Downloading PDB structure '7m7z'...
# Downloading PDB structure '4dei'...
# Downloading PDB structure '1ghz'...
# Downloading PDB structure '2ohn'...
# Downloading PDB structure '7gg7'...
# Downloading PDB structure '7ge8'...
# Downloading PDB structure '2r9o'...
# Downloading PDB structure '7o1u'...
# Downloading PDB structure '2bu5'...
# Downloading PDB structure '7af0'...
# Downloading PDB structure '6s45'...
# Downloading PDB structure '4bs5'...
# Downloading PDB structure '4d13'...
# Downloading PDB structure '3m57'...
# Downloading PDB structure '4rzq'...
# Downloading PDB structure '7m82'...
# Downloading PDB structure '7gh4'...
# Downloading PDB structure '7n44'...
# Downloading PDB structure '6c17'...
# Downloading PDB structure '7gcz'...
# Downloading PDB structure '1yyz'...
# Downloading PDB structure '1gi0'...
# Downloading PDB structure '7kcf'...
# Downloading PDB structure '4ucs'...
# Downloading PDB structure '5nw7'...
# Downloading PDB structure '8ty5'...
# Downloading PDB structure '3fxm'...
# Downloading PDB structure '6w63'...
# Downloading PDB structure '1std'...
# Downloading PDB structure '3tp8'...
# Downloading PDB structure '1tx7'...
# Downloading PDB structure '7ge2'...
# Downloading PDB structure '1nv3'...
# Downloading PDB structure '7gdv'...
# Downloading PDB structure '5kfy'...
# Downloading PDB structure '6bss'...
# Downloading PDB structure '6zau'...
# Downloading PDB structure '4x6h'...
# Downloading PDB structure '7gd4'...
# Downloading PDB structure '4j0p'...
# Downloading PDB structure '1nuw'...
# Downloading PDB structure '1f9u'...
# Downloading PDB structure '5nwb'...
# Downloading PDB structure '8a23'...
# Downloading PDB structure '5hji'...
# Downloading PDB structure '7wo1'...
# Downloading PDB structure '7au4'...
# Downloading PDB structure '3m53'...
# Downloading PDB structure '7kda'...
# Downloading PDB structure '3cku'...
# Downloading PDB structure '3udj'...
# Downloading PDB structure '4j1f'...
# Downloading PDB structure '4i1c'...
# Downloading PDB structure '4i6h'...
# Downloading PDB structure '4i0d'...
# Downloading PDB structure '8s5y'...
# Downloading PDB structure '2agk'...
# Downloading PDB structure '8qy3'...
# Downloading PDB structure '2au6'...
# Downloading PDB structure '5smn'...
# Downloading PDB structure '6p1q'...
# Downloading PDB structure '8i4s'...
# Downloading PDB structure '7gdx'...
# Downloading PDB structure '5eh0'...
# Downloading PDB structure '7slv'...
# Downloading PDB structure '7ap1'...
# Downloading PDB structure '6qsa'...
# Downloading PDB structure '7ghg'...
# Downloading PDB structure '7gee'...
# Downloading PDB structure '4x6i'...
# Downloading PDB structure '5kg6'...
# Downloading PDB structure '3lcc'...
# Downloading PDB structure '8ex0'...
# Downloading PDB structure '7d8q'...
# Downloading PDB structure '6rc5'...
# Downloading PDB structure '7sgu'...
# Downloading PDB structure '4i6f'...
# Downloading PDB structure '1y5a'...
# Downloading PDB structure '1o3c'...
# Downloading PDB structure '4j17'...
# Downloading PDB structure '1o37'...
# Downloading PDB structure '7geo'...
# Downloading PDB structure '7d21'...
# Downloading PDB structure '3nhh'...
# Downloading PDB structure '3ine'...
# Downloading PDB structure '4ivt'...
# Downloading PDB structure '3awo'...
# Downloading PDB structure '4bui'...
# Downloading PDB structure '7enl'...
# Downloading PDB structure '4zpe'...
# Downloading PDB structure '4j0z'...
# Downloading PDB structure '6jfr'...
# Downloading PDB structure '3fve'...
# Downloading PDB structure '8pgz'...
# Downloading PDB structure '7gei'...
# Downloading PDB structure '8qe2'...
# Downloading PDB structure '5kh6'...
# Downloading PDB structure '8bjd'...
# Downloading PDB structure '1fhv'...
# Downloading PDB structure '8qe0'...
# Downloading PDB structure '5eqv'...
# Downloading PDB structure '5rwd'...
# Downloading PDB structure '7m7n'...
# Downloading PDB structure '7d8d'...
# Downloading PDB structure '1pd9'...
# Downloading PDB structure '4d12'...
# Downloading PDB structure '1qzy'...
# Downloading PDB structure '7geu'...
# Downloading PDB structure '7jiw'...
# Downloading PDB structure '5tkr'...
# Downloading PDB structure '1wkr'...
# Downloading PDB structure '1g3d'...
# Downloading PDB structure '6dpd'...
# Downloading PDB structure '7ge3'...
# Downloading PDB structure '7gew'...
# Downloading PDB structure '8k6d'...
# Downloading PDB structure '1tkh'...
# Downloading PDB structure '8veq'...
# Downloading PDB structure '3vg1'...
# Downloading PDB structure '8pa8'...
# Downloading PDB structure '1g9a'...
# Downloading PDB structure '5kg7'...
# Downloading PDB structure '7ggu'...
# Downloading PDB structure '4j1h'...
# Downloading PDB structure '7gdp'...
# Downloading PDB structure '3hxu'...
# Downloading PDB structure '7gfd'...
# Downloading PDB structure '1pph'...
# Downloading PDB structure '7uyc'...
# Downloading PDB structure '4ucu'...
# Downloading PDB structure '1gi5'...
# Downloading PDB structure '6kwh'...
# Downloading PDB structure '7gex'...
# Downloading PDB structure '7gfx'...
# Downloading PDB structure '7ggf'...
# Downloading PDB structure '3bdc'...
# Downloading PDB structure '8shr'...
# Downloading PDB structure '6wco'...
# Downloading PDB structure '7uya'...
# Downloading PDB structure '5kt7'...
# Downloading PDB structure '6tpm'...
# Downloading PDB structure '1v45'...
# Downloading PDB structure '6wad'...
# Downloading PDB structure '7d5a'...
# Downloading PDB structure '1pf7'...
# Downloading PDB structure '6k36'...
# Downloading PDB structure '7gfl'...
# Downloading PDB structure '6m72'...
# Downloading PDB structure '1v2o'...
# Downloading PDB structure '1qdq'...
# Downloading PDB structure '7gg3'...
# Downloading PDB structure '7gek'...
# Downloading PDB structure '4hlm'...
# Downloading PDB structure '2dcd'...
# Downloading PDB structure '8qy2'...
# Downloading PDB structure '4eep'...
# Downloading PDB structure '6oh9'...
# Downloading PDB structure '7ges'...
# Downloading PDB structure '4rno'...
# Downloading PDB structure '8b76'...
# Downloading PDB structure '3cuj'...
# Downloading PDB structure '7geq'...
# Downloading PDB structure '4rcd'...
# Downloading PDB structure '6vf5'...
# Downloading PDB structure '3uaz'...
# Downloading PDB structure '3d5x'...
# Downloading PDB structure '5ayf'...
# Downloading PDB structure '7kir'...
# Downloading PDB structure '2fub'...
# Downloading PDB structure '1sqf'...
# Downloading PDB structure '6rc4'...
# Downloading PDB structure '4ui4'...
# Downloading PDB structure '8rgd'...
# Downloading PDB structure '6kkv'...
# Downloading PDB structure '6pxf'...
# Downloading PDB structure '7gev'...
# Downloading PDB structure '4r8q'...
# Downloading PDB structure '6kdu'...
# Downloading PDB structure '3wyx'...
# Downloading PDB structure '8qii'...
# Downloading PDB structure '7vic'...
# Downloading PDB structure '8axz'...
# Downloading PDB structure '2est'...
# Downloading PDB structure '2age'...
# Downloading PDB structure '6rce'...
# Downloading PDB structure '3uay'...
# Downloading PDB structure '8eni'...
# Downloading PDB structure '8b49'...
# Downloading PDB structure '1tu6'...
# Downloading PDB structure '5c1y'...
# Downloading PDB structure '3udd'...
# Downloading PDB structure '6p1p'...
# Downloading PDB structure '1tx8'...
# Downloading PDB structure '3v8q'...
# Downloading PDB structure '6pyr'...
# Downloading PDB structure '1rtl'...
# Downloading PDB structure '7z3j'...
# Downloading PDB structure '8acd'...
# Downloading PDB structure '6lj1'...
# Downloading PDB structure '5bsb'...
# Downloading PDB structure '1w6y'...
# Downloading PDB structure '6rgm'...
# Downloading PDB structure '8r5t'...
# Downloading PDB structure '4ehx'...
# Downloading PDB structure '2ex6'...
# Downloading PDB structure '2ai7'...
# Downloading PDB structure '9f6k'...
# Downloading PDB structure '2f1g'...
# Downloading PDB structure '8am0'...
# Downloading PDB structure '6lj7'...
# Downloading PDB structure '8pg7'...
# Downloading PDB structure '8hei'...
# Downloading PDB structure '5c5r'...
# Downloading PDB structure '8ru9'...
# Downloading PDB structure '8qio'...
# Downloading PDB structure '5bvc'...
# Downloading PDB structure '6lj8'...
# Downloading PDB structure '6m0k'...
# Downloading PDB structure '6no1'...
# Downloading PDB structure '1ri3'...
# Downloading PDB structure '1y5b'...
# Downloading PDB structure '8rfv'...
# Downloading PDB structure '1tlo'...
# Downloading PDB structure '1u68'...
# Downloading PDB structure '1yxi'...
# Downloading PDB structure '1w66'...
# Downloading PDB structure '5ap6'...
# Downloading PDB structure '1v2q'...
# Downloading PDB structure '6no3'...
# Downloading PDB structure '1y59'...
# Downloading PDB structure '7gg4'...
# Downloading PDB structure '6jed'...
# Downloading PDB structure '8skh'...
# Downloading PDB structure '7uyb'...
# Downloading PDB structure '1rgz'...
# Downloading PDB structure '5c3x'...
# Downloading PDB structure '5c5p'...
# Downloading PDB structure '1rsm'...
# Downloading PDB structure '7gfg'...
# Downloading PDB structure '5c5q'...
# Downloading PDB structure '6n33'...
# Downloading PDB structure '4uco'...
# Downloading PDB structure '2br0'...
# Downloading PDB structure '5w07'...
# Processed CSV saved to /Users/shayneskrtic/Desktop/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible_Chains.csv

# %%
import requests
from Bio import PDB

def get_protein_sequence_length(pdb_id):
    try:
        # Download the PDB file
        url = f"https://files.rcsb.org/download/{pdb_id}.pdb"
        response = requests.get(url)
        response.raise_for_status()
        
        # Save the PDB file locally
        pdb_file = f"{pdb_id}.pdb"
        with open(pdb_file, 'wb') as file:
            file.write(response.content)
        
        # Create a PDB parser
        parser = PDB.PDBParser(QUIET=True)
        
        # Parse the structure
        structure = parser.get_structure(pdb_id, pdb_file)
        
        # Get the sequence length
        sequence_length = 1
        for model in structure:
            for chain in model:
                for residue in chain:
                    if PDB.is_aa(residue):
                        sequence_length += 1
        
        return sequence_length
    except requests.HTTPError as http_err:
        return f"HTTP error occurred: {http_err}"
    except FileNotFoundError:
        return f"FileNotFoundError: The PDB file for ID '{pdb_id}' could not be found."
    except Exception as e:
        return f"An error occurred: {e}"

# Example usage
pdb_id = "7MRR"  # Replace with your PDB ID
sequence_length = get_protein_sequence_length(pdb_id)
print(f"The sequence length of the protein with PDB ID {pdb_id} is {sequence_length}.")
# Out:
# The sequence length of the protein with PDB ID 7MRR is 310.

# %%
import csv
import requests
from Bio import PDB

def get_protein_sequence_length(pdb_id):
    try:
        # Download the PDB file
        url = f"https://files.rcsb.org/download/{pdb_id}.pdb"
        response = requests.get(url)
        response.raise_for_status()
        
        # Save the PDB file locally
        pdb_file = f"{pdb_id}.pdb"
        with open(pdb_file, 'wb') as file:
            file.write(response.content)
        
        # Create a PDB parser
        parser = PDB.PDBParser(QUIET=True)
        
        # Parse the structure
        structure = parser.get_structure(pdb_id, pdb_file)
        
        # Get the sequence length
        sequence_length = 0
        for model in structure:
            for chain in model:
                for residue in chain:
                    if PDB.is_aa(residue):
                        sequence_length += 1
        
        return sequence_length
    except requests.HTTPError as http_err:
        return f"HTTP error occurred: {http_err}"
    except FileNotFoundError:
        return f"FileNotFoundError: The PDB file for ID '{pdb_id}' could not be found."
    except Exception as e:
        return f"An error occurred: {e}"

def add_sequence_length_to_csv(input_csv, output_csv):
    with open(input_csv, mode='r') as infile, open(output_csv, mode='w', newline='') as outfile:
        reader = csv.DictReader(infile)
        fieldnames = reader.fieldnames + ['sequence_length']
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for row in reader:
            pdb_id = row['pdb_id']
            sequence_length = get_protein_sequence_length(pdb_id)
            row['sequence_length'] = sequence_length
            writer.writerow(row)

# Example usage
input_csv = '/Users/shayneskrtic/Desktop/ML_DATA/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible_Chains.csv'  
output_csv = '/Users/shayneskrtic/Desktop/ML_DATA/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible_Chains_betterSeqLength.csv'  # Replace with your desired output CSV file path
add_sequence_length_to_csv(input_csv, output_csv)

# %%
import pandas as pd
import ast

def load_and_extract_signatures(csv_file_path):
    df = pd.read_csv(csv_file_path)
    unique_signatures = set()
    
    for motifs in df['motifs'].fillna('[]'):
        motifs_list = ast.literal_eval(motifs)
        for motif in motifs_list:
            unique_signatures.add(motif['signature_ac'])
    
    unique_signatures_list = sorted(list(unique_signatures))
    return unique_signatures_list

def one_hot_encode_motifs(df, unique_signatures):
    # Initialize a DataFrame with zeros
    one_hot_df = pd.DataFrame(0, index=df.index, columns=unique_signatures)
    
    for i, motifs in enumerate(df['motifs'].fillna('[]')):
        motifs_list = ast.literal_eval(motifs)
        for motif in motifs_list:
            signature_ac = motif['signature_ac']
            if signature_ac in one_hot_df.columns:
                one_hot_df.at[i, signature_ac] = 1
    
    return one_hot_df

# Load the original DataFrame
csv_file_path = '/Users/shayneskrtic/Desktop/ML_DATA/data_copy_dropped_null_ec_OHE_AAS_Dropped_impossible_Chains_betterSeqLength_newest.csv'
df = pd.read_csv(csv_file_path)

# Extract unique signatures
unique_signatures = load_and_extract_signatures(csv_file_path)

# One-hot encode the motifs
one_hot_df = one_hot_encode_motifs(df, unique_signatures)

# Merge the one-hot encoded DataFrame with the original DataFrame
result_df = pd.concat([df, one_hot_df], axis=1)

# Save the result to a new CSV file
output_csv_file_path = '/Users/shayneskrtic/Desktop/ML_DATA/data_with_one_hot_encoded_motifs.csv'
result_df.to_csv(output_csv_file_path, index=False)

print(f"One-hot encoded DataFrame saved to {output_csv_file_path}")
# Out:
# One-hot encoded DataFrame saved to /Users/shayneskrtic/Desktop/ML_DATA/data_with_one_hot_encoded_motifs.csv

# %%
import pandas as pd
import ast

def extract_first_two_ec_numbers(ec_numbers):
    if pd.isna(ec_numbers):
        return None, None
    ec_list = ast.literal_eval(ec_numbers)
    if not ec_list:
        return None, None
    first_ec = ec_list[0]
    first_two_numbers = first_ec.split('.')[:2]
    return int(first_two_numbers[0]), int(first_two_numbers[1])

def add_ec_number_columns(csv_file_path, output_csv_file_path):
    df = pd.read_csv(csv_file_path)
    
    df[['ec_first', 'ec_second']] = df['ec_numbers'].apply(
        lambda x: pd.Series(extract_first_two_ec_numbers(x))
    )
    
    df.to_csv(output_csv_file_path, index=False)
    print(f"Updated DataFrame saved to {output_csv_file_path}")

# Example usage
csv_file_path = '/Users/shayneskrtic/Desktop/ML_DATA/data_with_one_hot_encoded_motifs.csv'  # Replace with your input CSV file path
output_csv_file_path = '/Users/shayneskrtic/Desktop/ML_DATA/newest_data.csv'  # Replace with your desired output CSV file path
add_ec_number_columns(csv_file_path, output_csv_file_path)
# Out:
# Updated DataFrame saved to /Users/shayneskrtic/Desktop/ML_DATA/newest_data.csv
