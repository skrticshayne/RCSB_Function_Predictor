# %% [markdown]
# # FIRST OUTLINE THINGS TO DO
# ## Connect To API
# ## Pull all features
# ## Add feature to column in DF
# ## Write DF to an Excel

# %%
import requests
import pandas as pd

# Define the API endpoint and query parameters
url = "https://search.rcsb.org/rcsbsearch/v2/query"
query = {
    "query": {
        "type": "terminal",
        "service": "text",
        "parameters": {
            "attribute": "rcsb_accession_info.deposit_date",
            "operator": "exists"
        }
    },
    "return_type": "entry",
    "request_options": {
        "paginate": {
            "start": 0,
            "rows": 100
        }
    }
}

# Send the request to the RCSB PDB API
response = requests.post(url, json=query)
data = response.json()

# Check the structure of the response
print(data)

# Extract the list of PDB IDs if 'result_set' is present
if 'result_set' in data:
    pdb_ids = [entry['identifier'] for entry in data['result_set']]
    # Convert the list to a DataFrame
    df = pd.DataFrame(pdb_ids, columns=['PDB_ID'])
    # Filter out CSM PDBs (assuming CSM PDBs have a specific pattern in their IDs)
    non_csm_df = df[~df['PDB_ID'].str.contains('CSM')]
    # Display the DataFrame
    display(non_csm_df)
else:
    print("The key 'result_set' was not found in the response.")
# Out:
# {'query_id': 'd08abd44-297e-4002-910d-e9a0b1189881', 'result_type': 'entry', 'total_count': 227111, 'result_set': [{'identifier': '100D', 'score': 1.0}, {'identifier': '101D', 'score': 1.0}, {'identifier': '101M', 'score': 1.0}, {'identifier': '102D', 'score': 1.0}, {'identifier': '102L', 'score': 1.0}, {'identifier': '102M', 'score': 1.0}, {'identifier': '103D', 'score': 1.0}, {'identifier': '103L', 'score': 1.0}, {'identifier': '103M', 'score': 1.0}, {'identifier': '104D', 'score': 1.0}, {'identifier': '104L', 'score': 1.0}, {'identifier': '104M', 'score': 1.0}, {'identifier': '105D', 'score': 1.0}, {'identifier': '105M', 'score': 1.0}, {'identifier': '106D', 'score': 1.0}, {'identifier': '106M', 'score': 1.0}, {'identifier': '107D', 'score': 1.0}, {'identifier': '107L', 'score': 1.0}, {'identifier': '107M', 'score': 1.0}, {'identifier': '108D', 'score': 1.0}, {'identifier': '108L', 'score': 1.0}, {'identifier': '108M', 'score': 1.0}, {'identifier': '109D', 'score': 1.0}, {'identifier': '109L', 'score': 1.0}, {'identifier': '109M', 'score': 1.0}, {'identifier': '10GS', 'score': 1.0}, {'identifier': '10MH', 'score': 1.0}, {'identifier': '110D', 'score': 1.0}, {'identifier': '110L', 'score': 1.0}, {'identifier': '110M', 'score': 1.0}, {'identifier': '111D', 'score': 1.0}, {'identifier': '111L', 'score': 1.0}, {'identifier': '111M', 'score': 1.0}, {'identifier': '112D', 'score': 1.0}, {'identifier': '112L', 'score': 1.0}, {'identifier': '112M', 'score': 1.0}, {'identifier': '113D', 'score': 1.0}, {'identifier': '113L', 'score': 1.0}, {'identifier': '114D', 'score': 1.0}, {'identifier': '114L', 'score': 1.0}, {'identifier': '115D', 'score': 1.0}, {'identifier': '115L', 'score': 1.0}, {'identifier': '116D', 'score': 1.0}, {'identifier': '117D', 'score': 1.0}, {'identifier': '117E', 'score': 1.0}, {'identifier': '118D', 'score': 1.0}, {'identifier': '118L', 'score': 1.0}, {'identifier': '119D', 'score': 1.0}, {'identifier': '119L', 'score': 1.0}, {'identifier': '11AS', 'score': 1.0}, {'identifier': '11BA', 'score': 1.0}, {'identifier': '11BG', 'score': 1.0}, {'identifier': '11GS', 'score': 1.0}, {'identifier': '120L', 'score': 1.0}, {'identifier': '121D', 'score': 1.0}, {'identifier': '121P', 'score': 1.0}, {'identifier': '122D', 'score': 1.0}, {'identifier': '122L', 'score': 1.0}, {'identifier': '123D', 'score': 1.0}, {'identifier': '123L', 'score': 1.0}, {'identifier': '124D', 'score': 1.0}, {'identifier': '125L', 'score': 1.0}, {'identifier': '126D', 'score': 1.0}, {'identifier': '126L', 'score': 1.0}, {'identifier': '127D', 'score': 1.0}, {'identifier': '127L', 'score': 1.0}, {'identifier': '128D', 'score': 1.0}, {'identifier': '128L', 'score': 1.0}, {'identifier': '129D', 'score': 1.0}, {'identifier': '129L', 'score': 1.0}, {'identifier': '12AS', 'score': 1.0}, {'identifier': '12CA', 'score': 1.0}, {'identifier': '12E8', 'score': 1.0}, {'identifier': '12GS', 'score': 1.0}, {'identifier': '130D', 'score': 1.0}, {'identifier': '130L', 'score': 1.0}, {'identifier': '131D', 'score': 1.0}, {'identifier': '131L', 'score': 1.0}, {'identifier': '132D', 'score': 1.0}, {'identifier': '132L', 'score': 1.0}, {'identifier': '133D', 'score': 1.0}, {'identifier': '133L', 'score': 1.0}, {'identifier': '134D', 'score': 1.0}, {'identifier': '134L', 'score': 1.0}, {'identifier': '135D', 'score': 1.0}, {'identifier': '135L', 'score': 1.0}, {'identifier': '136D', 'score': 1.0}, {'identifier': '137D', 'score': 1.0}, {'identifier': '137L', 'score': 1.0}, {'identifier': '138D', 'score': 1.0}, {'identifier': '138L', 'score': 1.0}, {'identifier': '139D', 'score': 1.0}, {'identifier': '139L', 'score': 1.0}, {'identifier': '13GS', 'score': 1.0}, {'identifier': '13PK', 'score': 1.0}, {'identifier': '140D', 'score': 1.0}, {'identifier': '140L', 'score': 1.0}, {'identifier': '141D', 'score': 1.0}, {'identifier': '141L', 'score': 1.0}, {'identifier': '142D', 'score': 1.0}]}
#    PDB_ID
# 0    100D
# 1    101D
# 2    101M
# 3    102D
# 4    102L
# ..    ...
# 95   140D
# 96   140L
# 97   141D
# 98   141L
# 99   142D
#
# [100 rows x 1 columns]

# %%
import requests

def pdb_to_uniprot(pdb_id):
    # Define the API endpoint for the specific PDB ID
    url = f"https://www.ebi.ac.uk/pdbe/api/mappings/uniprot/{pdb_id}"
    
    # Send the request to the PDBe API
    response = requests.get(url)
    if response.status_code == 404:
        print(f"PDB ID {pdb_id} not found (HTTP Error 404).")
        return None
    
    content = response.json()
    
    # Extract UniProt IDs
    uniprot_ids = []
    if pdb_id.lower() in content:
        for uniprot in content[pdb_id.lower()]['UniProt'].keys():
            uniprot_ids.append(uniprot)
    
    return uniprot_ids

# %%
import requests

def get_protein_info(uniprot_id):
    # Define the API endpoint for the specific UniProt ID
    url = f"https://rest.uniprot.org/uniprotkb/{uniprot_id}.json"
    
    # Send the request to the UniProt API
    response = requests.get(url)
    data = response.json()
    return data

def get_protein_sequence(uniprot_id):
    url = f"https://rest.uniprot.org/uniprotkb/{uniprot_id}.json"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve sequence for UniProt ID {uniprot_id}")
        return 'N/A'

    data = response.json()
    sequence = data.get('sequence', {}).get('value', 'N/A')
    return sequence
        
def extract_ec_numbers(protein_info):
    ec_numbers = []
    for comment in protein_info.get('comments', []):
        if comment.get('commentType') == 'CATALYTIC ACTIVITY':
            reaction = comment.get('reaction', {})
            ec_number = reaction.get('ecNumber')
            if ec_number:
                ec_numbers.append(ec_number)
    return ec_numbers

def do_all(uniprot_id):
    protein_info = get_protein_info(uniprot_id)
    if not protein_info:
        return None
    
    # Extract relevant information from the protein_info JSON
    protein_name = protein_info.get('proteinDescription', {}).get('recommendedName', {}).get('fullName', {}).get('value', 'N/A')
    organism = protein_info.get('organism', {}).get('scientificName', 'N/A')
    gene_name = protein_info.get('genes', [{}])[0].get('geneName', {}).get('value', 'N/A')
    ec_numbers = extract_ec_numbers(protein_info)
    sequence = get_protein_sequence(uniprot_id)
    
    return {
        'protein_name': protein_name,
        'organism': organism,
        'gene_name': gene_name,
        'ec_numbers': ec_numbers,
        'sequence': sequence
    }

# %%
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("samiraalipour/rcsb-pdb-macromolecular-structure-dataset")
# Out:
# Requirement already satisfied: kagglehub in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (0.3.3)
# Requirement already satisfied: packaging in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from requests->kagglehub) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./VS-Code/ic01-python_intro/venv/lib/python3.12/site-packages (from requests->kagglehub) (2024.8.30)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv('/Users/carmenshero/Desktop/2/rcsb_pdb_Files/rcsb_pdb_Files/rcsb_pdb_StructureData.csv')
df2 = df["Entry ID"]
print(df2)
# Out:
# 0        6SJZ
# 1        5C37
# 2        6NNA
# 3        7M4C
# 4        7M4E
#          ...
# 11847    6T3M
# 11848    6WLX
# 11849    8D6J
# 11850    7C6B
# 11851    7D7U
# Name: Entry ID, Length: 11852, dtype: object

# %%
import pandas as pd

output_data = []

for pdb_id in df2[:200]:
    uniprot_id = pdb_to_uniprot(pdb_id)
    if uniprot_id:  # Ensure uniprot_id is not empty
        print(f"Processing PDB ID: {pdb_id}, UniProt IDs: {uniprot_id}")
        protein_info = do_all(uniprot_id[0])
        
        if protein_info is None:
            print(f"No data returned for UniProt ID {uniprot_id[0]}")
            output_data.append({
                'PDB_ID': pdb_id,
                'UniProt_IDs': ', '.join(uniprot_id),
                'Protein_Name': 'N/A',
                'Organism': 'N/A',
                'Gene_Name': 'N/A',
                'EC_Numbers': 'N/A',
                'Sequence': 'N/A'
            })
        else:
            # Extract data
            protein_name = protein_info['protein_name']
            organism = protein_info['organism']
            gene_name = protein_info['gene_name']
            ec_numbers = protein_info['ec_numbers']
            sequence = protein_info['sequence']
            #print(protein_info)
            print() #Blank line for readability
            # Print the data for verification
            #print(f"Protein Name: {protein_name}")
           # print(f"Organism: {organism}")
           # print(f"Gene Name: {gene_name}")
           # print(f"The EC numbers for UniProt ID {uniprot_id[0]} are: {ec_numbers if ec_numbers else 'N/A'}")
            
            
            output_data.append({
                'PDB_ID': pdb_id,
                'UniProt_IDs': ', '.join(uniprot_id),
                'Protein_Name': protein_name,
                'Organism': organism,
                'Gene_Name': gene_name,
                'EC_Numbers': ', '.join(ec_numbers) if ec_numbers else 'N/A',
                'Sequence': sequence
            })
    else:
        print(f"No UniProt ID found for PDB ID {pdb_id}")
# Out:
# Processing PDB ID: 6SJZ, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 5C37, UniProt IDs: ['P49327']
#
# Processing PDB ID: 6NNA, UniProt IDs: ['P49327']
#
# Processing PDB ID: 7M4C, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4E, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4F, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4H, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4I, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4L, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 5OOG, UniProt IDs: ['P30043']
#
# Processing PDB ID: 6QRM, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 6SK2, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 6SKJ, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 7M44, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M46, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M47, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4A, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4B, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M49, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M45, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4D, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4G, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4J, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M4K, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 8Q24, UniProt IDs: ['P30419']
#
# Processing PDB ID: 7UN7, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 8Q23, UniProt IDs: ['P30419']
#
# Processing PDB ID: 7M48, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M43, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 5IRQ, UniProt IDs: ['P05093']
#
# Processing PDB ID: 6SK3, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 6SK8, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 6HFQ, UniProt IDs: ['P27708']
#
# Processing PDB ID: 5YNZ, UniProt IDs: ['P27708']
#
# Processing PDB ID: 6HG1, UniProt IDs: ['P27708', 'P05020']
#
# Processing PDB ID: 6HFN, UniProt IDs: ['P27708']
#
# Processing PDB ID: 6HFP, UniProt IDs: ['P27708']
#
# Processing PDB ID: 4WJX, UniProt IDs: ['Q13231']
#
# Processing PDB ID: 6VF0, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF4, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VFB, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 7OWN, UniProt IDs: ['P30419']
#
# Processing PDB ID: 7OWP, UniProt IDs: ['P30419']
#
# Processing PDB ID: 7OWR, UniProt IDs: ['P30419']
#
# Processing PDB ID: 5IIJ, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 6UOL, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RPZ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ0, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ2, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ4, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ5, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ6, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ8, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7M0A, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 7M0C, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 6Z1W, UniProt IDs: ['P51659']
#
# Processing PDB ID: 6Z1X, UniProt IDs: ['P51659']
#
# Processing PDB ID: 5TBA, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5TBB, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5V1I, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5V1O, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5V1R, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6ILD, UniProt IDs: ['Q15046', 'Q13155']
#
# Processing PDB ID: 4RPY, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6ZE8, UniProt IDs: ['Q13231']
#
# Processing PDB ID: 5U9H, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4D4Z, UniProt IDs: ['Q9BU89']
#
# Processing PDB ID: 6I7K, UniProt IDs: ['Q9BVA6']
#
# Processing PDB ID: 7OWO, UniProt IDs: ['P30419']
#
# Processing PDB ID: 5O9V, UniProt IDs: ['P30419', 'Q96NN9']
#
# Processing PDB ID: 5TZV, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6EZB, UniProt IDs: ['Q9NX74']
#
# Processing PDB ID: 5EOZ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7OWU, UniProt IDs: ['P30419']
#
# Processing PDB ID: 6FLM, UniProt IDs: ['Q14258']
#
# Processing PDB ID: 4YMO, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4YN4, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4YMN, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6YWU, UniProt IDs: ['P11172']
#
# Processing PDB ID: 6CU9, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CUA, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CUB, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4Z6E, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4Z6F, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7AOU, UniProt IDs: ['Q13451']
#
# Processing PDB ID: 4Z6C, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4Z6D, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6EZA, UniProt IDs: ['Q9NX74']
#
# Processing PDB ID: 6EZC, UniProt IDs: ['Q9NX74']
#
# Processing PDB ID: 5DBA, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4YMM, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ0, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7RBI, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7RBJ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7RBK, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7RBL, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7RBM, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5VS0, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5VS3, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5VS4, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NFL, UniProt IDs: ['Q9UH17']
#
# Processing PDB ID: 6N2R, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6N2S, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6N2T, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKR, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKS, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKT, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKU, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKV, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKW, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKX, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NKY, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6NL0, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7BO5, UniProt IDs: ['Q6P988']
#
# Processing PDB ID: 8OKT, UniProt IDs: ['P00918']
#
# Processing PDB ID: 8OMB, UniProt IDs: ['P00918']
#
# Processing PDB ID: 4WK9, UniProt IDs: ['Q13231']
#
# Processing PDB ID: 4WKF, UniProt IDs: ['Q13231']
#
# Processing PDB ID: 4WKH, UniProt IDs: ['Q13231']
#
# Processing PDB ID: 5HPT, UniProt IDs: ['Q9H0M0', 'P62987', 'P68036']
#
# Processing PDB ID: 6W13, UniProt IDs: ['O15527']
#
# Processing PDB ID: 4YGK, UniProt IDs: ['P00918']
#
# Processing PDB ID: 4YGL, UniProt IDs: ['P00918']
#
# Processing PDB ID: 4XZF, UniProt IDs: ['Q14527']
#
# Processing PDB ID: 6CLY, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CPQ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6E3X, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ1, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ2, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ3, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ4, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7MZ8, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DB6, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DB7, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DB8, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DB9, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DBB, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5DBC, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CRH, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6E3R, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6E3V, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6E3W, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR3, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6U2O, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RPX, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ1, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ3, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4RQ7, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5UGP, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5V1J, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6BTE, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4XUS, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 6FZ5, UniProt IDs: ['P30419']
#
# Processing PDB ID: 5VRY, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5VRZ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5U2R, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5U2S, UniProt IDs: ['P06746']
#
# Processing PDB ID: 5U2T, UniProt IDs: ['P06746']
#
# Processing PDB ID: 4XA5, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 4WTV, UniProt IDs: ['Q8TCG2', 'P00720']
#
# Processing PDB ID: 6DIM, UniProt IDs: ['Q9NUW8']
#
# Processing PDB ID: 6DJD, UniProt IDs: ['Q9NUW8']
#
# Processing PDB ID: 6VEZ, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF1, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF2, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF3, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF5, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF6, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF7, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF8, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VF9, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VFA, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 6VFC, UniProt IDs: ['Q9NP87']
#
# Processing PDB ID: 4X5V, UniProt IDs: ['Q9UGP5']
#
# Processing PDB ID: 6BEM, UniProt IDs: ['P06746']
#
# Processing PDB ID: 7WUZ, UniProt IDs: ['Q9Y4U1']
#
# Processing PDB ID: 6BEL, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR4, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR5, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR6, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR7, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR8, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CR9, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CRB, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CRC, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTI, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTJ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTK, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTL, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTM, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTN, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTO, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTP, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTQ, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTU, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTV, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTW, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6CTX, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6G2Q, UniProt IDs: ['P06746']
#
# Processing PDB ID: 6BTF, UniProt IDs: ['P06746']

# %%
import os

# Dynamically get the path to the user's desktop
desktop_path = os.path.expanduser('~/Desktop')
output_directory = os.path.join(desktop_path, 'RCSB_Datasets')

# Create the RCSB_Datasets directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Convert the collected data to a DataFrame
output_df = pd.DataFrame(output_data)

# Specify the output file path
output_file_path = f'{output_directory}/RCSB_updated.csv'

# Save the DataFrame to a CSV file
output_df.to_csv(output_file_path, index=False)

print(f"Data successfully saved to {output_file_path}")
# Out:
# Data successfully saved to /Users/carmenshero/Desktop/RCSB_Datasets/RCSB_updated.csv
